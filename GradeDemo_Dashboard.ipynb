# %%
#Import Libraries Needed
import pandas as pd
import geopandas as gpd
import panel as pn
pn.extension('plotly',comms='ipywidgets')
import param
import hvplot.pandas
import plotly.express as px
from urllib.request import urlopen
import plotly.graph_objects as go
import requests
from PIL import Image, ImageOps

# %%
#Import DataFrames
import json
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)
target_states = ['48']
counties['features'] = [f for f in counties['features'] if f['properties']['STATE'] in target_states]

# %%
#Import dataframes
address = ("Data/District_Loss/txcountyemploy.xlsx")
employ_df = pd.read_excel(address)

#Create a new dataframes with columns based on the differences of the 2021 Bureau of Labor Statistics Data and 
#2019 Bureau of Labor Statistics Data, divided by the 2019 data.
employ_df['NAME'] = employ_df['NAME'].str.replace(", TX","")
employ_df['YEAR']=employ_df['YEAR'].values.astype(str)
employ_df['YEAR'] = employ_df['YEAR'].str.replace("'","")
df_19 = employ_df[employ_df['YEAR'] == '2019']
df_20 = employ_df[employ_df['YEAR'] == '2020']
df_21 = employ_df[employ_df['YEAR'] == '2021']
df_20 =df_20.reset_index()
df_21=df_21.reset_index()
diff_df = pd.DataFrame()
diff_df = df_19[['NAME','FIPS']]
diff_df['Civilian Labor Force Difference (2021-2019)'] = (df_21['LABOR_FORCE']-df_19['LABOR_FORCE'])/df_19['LABOR_FORCE']
diff_df['Employed Persons Difference (2021-2019)']= (df_21['EMPLOYED']-df_19['EMPLOYED'])/df_19['EMPLOYED']
diff_df['Umemployed Persons Difference (2021-2019)']= (df_21['UNEMPLOYED']-df_19['UNEMPLOYED'])/df_19['UNEMPLOYED']
diff_df['Unemployment Rate Difference (2021-2019)']= (df_21['UNEMPLOYMENT_PCT']-df_19['UNEMPLOYMENT_PCT'])/df_19['UNEMPLOYMENT_PCT']
# Out:
# C:\Users\d_p327\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning:
#
# Workbook contains no default style, apply openpyxl's default
#
# C:\Users\d_p327\AppData\Local\Temp\ipykernel_13280\1615083697.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\d_p327\AppData\Local\Temp\ipykernel_13280\1615083697.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\d_p327\AppData\Local\Temp\ipykernel_13280\1615083697.py:19: SettingWithCopyWarning:
#
# ...

# %%
diff_df = diff_df.round(2)
diff_df.rename(columns={'NAME':'County Name','FIPS':'County #'},inplace=True)

# %% [markdown]
# # Texas County Level Map

# %%
demo_df = pd.read_csv('Data/District_Loss/demographic_grade_countylevel.csv')
demo22 = pd.read_csv('Data/District_Loss/DATA_Texas_District_v1.csv')

# %%
diff_df
# Out:
#          County Name  County #  Civilian Labor Force Difference (2021-2019)  \
# 0    Anderson County     48001                                         0.00
# 1     Andrews County     48003                                        -0.08
# 2    Angelina County     48005                                         0.01
# 3     Aransas County     48007                                         0.01
# 4      Archer County     48009                                         0.00
# ..               ...       ...                                          ...
# 249      Wood County     48499                                         0.03
# 250    Yoakum County     48501                                        -0.11
# 251     Young County     48503                                         0.02
# 252    Zapata County     48505                                        -0.11
# 253    Zavala County     48507                                        -0.01
#
#      Employed Persons Difference (2021-2019)  \
# ...

# %%
demo_df = demo_df.merge(diff_df, how='inner',on='County #')
demo_df
# Out:
#      Unnamed: 0  County #  Average Score Math Asian Grade 3 2018-2019  \
# 0             0     48001                                         NaN
# 1             1     48003                                         NaN
# 2             2     48005                                    0.927449
# 3             3     48007                                    0.848851
# 4             4     48009                                         NaN
# ..          ...       ...                                         ...
# 248         248     48499                                         NaN
# 249         249     48501                                         NaN
# 250         250     48503                                         NaN
# 251         251     48505                                         NaN
# 252         252     48507                                         NaN
#
#      Average Score Math Asian Grade 4 2018-2019  \
# 0                                           NaN
# ...

# %%
nan_cols = [i for i in demo_df.columns if demo_df[i].isnull().any()]
nan_cols2 = [i for i in demo22.columns if demo22[i].isnull().any()]

# %%
nan_cols2
# Out:
# ['Grade 3 2020-2021',
#  'Grade 3 2018-2019',
#  'Grade 4 2020-2021',
#  'Grade 4 2018-2019',
#  'Grade 5 2020-2021',
#  'Grade 5 2018-2019',
#  'Grade 6 2020-2021',
#  'Grade 6 2018-2019',
#  'Grade 7 2020-2021',
#  'Grade 7 2018-2019',
#  'Grade 8 2020-2021',
#  'Grade 8 2018-2019',
#  'Grades 9-12 2020-2021',
#  'Grades 9-12 2018-2019',
#  'Prek 2020-2021',
#  'Prek 2018-2019',
#  'K 2020-2021',
#  'K 2018-2019',
#  'Grade 1 2020-2021',
#  'Grade 1 2018-2019',
#  'Grade 2 2020-2021',
#  'Grade 2 2018-2019',
#  'Grade 9 2020-2021',
#  'Grade 9 2018-2019',
#  'Grade 10 2020-2021',
#  'Grade 10 2018-2019',
#  'Grade 11 2020-2021',
#  'Grade 11 2018-2019',
#  'Grade 12 2020-2021',
#  'Grade 12 2018-2019',
#  'Total Students 2021-2022',
#  'Grade 3 2021-2022',
#  'Grade 4 2021-2022',
#  'Grade 5 2021-2022',
#  'Grade 6 2021-2022',
#  'Grade 7 2021-2022',
#  'Grade 8 2021-2022',
#  'Grades 1-8 2021-2022',
#  'Grades 9-12 2021-2022',
#  'Prek 2021-2022',
#  'K 2021-2022',
# ...

# %%
with pd.option_context('mode.use_inf_as_na', True):
    demo_df.fillna(0,inplace=True)
    demo22.fillna(0,inplace=True)

# %%
nan_cols = [i for i in demo_df.columns if demo_df[i].isnull().any()]
nan_cols2 = [i for i in demo22.columns if demo22[i].isnull().any()]

# %%
nan_cols2
# Out:
# []

# %%
demo22.groupby('County #').mean().reset_index()
# Out:
# C:\Users\d_p327\AppData\Local\Temp\ipykernel_13280\1806659439.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#      County #    NCES_DISTR  Total Operational Public Schools 2018-2019  \
# 0       48001  4.828779e+06                                    3.571429
# 1       48003  4.808280e+06                                    6.000000
# 2       48005  4.821956e+06                                    6.142857
# 3       48007  4.808550e+06                                    5.000000
# 4       48009  4.826030e+06                                    2.666667
# ..        ...           ...                                         ...
# 248     48499  4.831740e+06                                    2.833333
# 249     48501  4.825905e+06                                    3.500000
# ...

# %%
nan_cols2 = [i for i in demo22.columns if demo22[i].isnull().any()]

# %%
nan_cols2
# Out:
# []

# %%
asian1921_3 = pd.DataFrame()
asian1922_3 = pd.DataFrame()
asian2122_3 = pd.DataFrame()

black1921_3 = pd.DataFrame()
black1922_3 = pd.DataFrame()
black2122_3 = pd.DataFrame()

all1921_3 = pd.DataFrame()
all1922_3 = pd.DataFrame()
all2122_3 = pd.DataFrame()

white1921_3 = pd.DataFrame()
white1922_3 = pd.DataFrame()
white2122_3 = pd.DataFrame()

freelunch1921_3 = pd.DataFrame()
freelunch1922_3 = pd.DataFrame()
freelunch2122_3 = pd.DataFrame()



hispanic1921_3 = pd.DataFrame()
hispanic1922_3 = pd.DataFrame()
hispanic2122_3 = pd.DataFrame()

poverty1921_3 = pd.DataFrame()
poverty1922_3 = pd.DataFrame()
poverty2122_3 = pd.DataFrame()

t11921_3 = pd.DataFrame()
t11922_3 = pd.DataFrame()
t12122_3 = pd.DataFrame()

specialed1921_3 = pd.DataFrame()
specialed1922_3 = pd.DataFrame()
specialed2122_3 = pd.DataFrame()

all1921_3['Math'] = (demo_df['Average Score Math All Grade 3 2020-2021'] - demo_df['Average Score Math All Grade 3 2018-2019'])/demo_df['Average Score Math All Grade 3 2018-2019']
all1921_3['Reading'] = (demo_df['Average Score Reading All Grade 3 2020-2021'] - demo_df['Average Score Reading All Grade 3 2018-2019'])/demo_df['Average Score Reading All Grade 3 2018-2019']
all1922_3['Math'] = (demo22['Average Score Math All Grade 3 2021-2022'] - demo_df['Average Score Math All Grade 3 2018-2019'])/demo_df['Average Score Math All Grade 3 2018-2019']
all1922_3['Reading'] = (demo22['Average Score Reading All Grade 3 2021-2022'] - demo_df['Average Score Reading All Grade 3 2018-2019'])/demo_df['Average Score Reading All Grade 3 2018-2019']
all2122_3['Math'] = (demo22['Average Score Math All Grade 3 2021-2022'] - demo_df['Average Score Math All Grade 3 2020-2021'])/demo_df['Average Score Math All Grade 3 2020-2021']
all2122_3['Reading'] = (demo22['Average Score Reading All Grade 3 2021-2022'] - demo_df['Average Score Reading All Grade 3 2020-2021'])/demo_df['Average Score Reading All Grade 3 2020-2021']

white1921_3['Math'] = (demo_df['Average Score Math White Grade 3 2020-2021'] - demo_df['Average Score Math White Grade 3 2018-2019'])/demo_df['Average Score Math White Grade 3 2018-2019']
white1921_3['Reading'] = (demo_df['Average Score Reading White Grade 3 2020-2021'] - demo_df['Average Score Reading White Grade 3 2018-2019'])/demo_df['Average Score Reading White Grade 3 2018-2019']
white1922_3['Math'] = (demo22['Average Score Math White Grade 3 2021-2022'] - demo_df['Average Score Math White Grade 3 2018-2019'])/demo_df['Average Score Math White Grade 3 2018-2019']
white1922_3['Reading'] = (demo22['Average Score Reading White Grade 3 2021-2022'] - demo_df['Average Score Reading White Grade 3 2018-2019'])/demo_df['Average Score Reading White Grade 3 2018-2019']
white2122_3['Math'] = (demo22['Average Score Math White Grade 3 2021-2022'] - demo_df['Average Score Math White Grade 3 2020-2021'])/demo_df['Average Score Math White Grade 3 2020-2021']
white2122_3['Reading'] = (demo22['Average Score Reading White Grade 3 2021-2022'] - demo_df['Average Score Reading White Grade 3 2020-2021'])/demo_df['Average Score Reading White Grade 3 2020-2021']

hispanic1921_3['Math'] = (demo_df['Average Score Math Hispanic Grade 3 2020-2021'] - demo_df['Average Score Math Hispanic Grade 3 2018-2019'])/demo_df['Average Score Math Hispanic Grade 3 2018-2019']
hispanic1921_3['Reading'] = (demo_df['Average Score Reading Hispanic Grade 3 2020-2021'] - demo_df['Average Score Reading Hispanic Grade 3 2018-2019'])/demo_df['Average Score Reading Hispanic Grade 3 2018-2019']
hispanic1922_3['Math'] = (demo22['Average Score Math Hispanic Grade 3 2021-2022'] - demo_df['Average Score Math Hispanic Grade 3 2018-2019'])/demo_df['Average Score Math Hispanic Grade 3 2018-2019']
hispanic1922_3['Reading'] = (demo22['Average Score Reading Hispanic Grade 3 2021-2022'] - demo_df['Average Score Reading Hispanic Grade 3 2018-2019'])/demo_df['Average Score Reading Hispanic Grade 3 2018-2019']
hispanic2122_3['Math'] = (demo22['Average Score Math Hispanic Grade 3 2021-2022'] - demo_df['Average Score Math Hispanic Grade 3 2020-2021'])/demo_df['Average Score Math Hispanic Grade 3 2020-2021']
hispanic2122_3['Reading'] = (demo22['Average Score Reading Hispanic Grade 3 2021-2022'] - demo_df['Average Score Reading Hispanic Grade 3 2020-2021'])/demo_df['Average Score Reading Hispanic Grade 3 2020-2021']

black1921_3['Math'] = (demo_df['Average Score Math Black Grade 3 2020-2021'] - demo_df['Average Score Math Black Grade 3 2018-2019'])/demo_df['Average Score Math Black Grade 3 2018-2019']
black1921_3['Reading'] = (demo_df['Average Score Reading Black Grade 3 2020-2021'] - demo_df['Average Score Reading Black Grade 3 2018-2019'])/demo_df['Average Score Reading Black Grade 3 2018-2019']
black1922_3['Math'] = (demo22['Average Score Math Black Grade 3 2021-2022'] - demo_df['Average Score Math Black Grade 3 2018-2019'])/demo_df['Average Score Math Black Grade 3 2018-2019']
black1922_3['Reading'] = (demo22['Average Score Reading Black Grade 3 2021-2022'] - demo_df['Average Score Reading Black Grade 3 2018-2019'])/demo_df['Average Score Reading Black Grade 3 2018-2019']
black2122_3['Math'] = (demo22['Average Score Math Black Grade 3 2021-2022'] - demo_df['Average Score Math Black Grade 3 2020-2021'])/demo_df['Average Score Math Black Grade 3 2020-2021']
black2122_3['Reading'] = (demo22['Average Score Reading Black Grade 3 2021-2022'] - demo_df['Average Score Reading Black Grade 3 2020-2021'])/demo_df['Average Score Reading Black Grade 3 2020-2021']

freelunch1921_3['Math'] = (demo_df['Average Score Math Free Lunch Grade 3 2020-2021'] - demo_df['Average Score Math Free Lunch Grade 3 2018-2019'])/demo_df['Average Score Math Free Lunch Grade 3 2018-2019']
freelunch1921_3['Reading'] = (demo_df['Average Score Reading Free Lunch Grade 3 2020-2021'] - demo_df['Average Score Reading Free Lunch Grade 3 2018-2019'])/demo_df['Average Score Reading Free Lunch Grade 3 2018-2019']
freelunch1922_3['Math'] = (demo22['Average Score Math Free Lunch Grade 3 2021-2022'] - demo_df['Average Score Math Free Lunch Grade 3 2018-2019'])/demo_df['Average Score Math Free Lunch Grade 3 2018-2019']
freelunch1922_3['Reading'] = (demo22['Average Score Reading Free Lunch Grade 3 2021-2022'] - demo_df['Average Score Reading Free Lunch Grade 3 2018-2019'])/demo_df['Average Score Reading Free Lunch Grade 3 2018-2019']
freelunch2122_3['Math'] = (demo22['Average Score Math Free Lunch Grade 3 2021-2022'] - demo_df['Average Score Math Free Lunch Grade 3 2020-2021'])/demo_df['Average Score Math Free Lunch Grade 3 2020-2021']
freelunch2122_3['Reading'] = (demo22['Average Score Reading Free Lunch Grade 3 2021-2022'] - demo_df['Average Score Reading Free Lunch Grade 3 2020-2021'])/demo_df['Average Score Reading Free Lunch Grade 3 2020-2021']

poverty1921_3['Math'] = (demo_df['Average Score Math Poverty Grade 3 2020-2021'] - demo_df['Average Score Math Poverty Grade 3 2018-2019'])/demo_df['Average Score Math Poverty Grade 3 2018-2019']
poverty1921_3['Reading'] = (demo_df['Average Score Reading Poverty Grade 3 2020-2021'] - demo_df['Average Score Reading Poverty Grade 3 2018-2019'])/demo_df['Average Score Reading Poverty Grade 3 2018-2019']
poverty1922_3['Math'] = (demo22['Average Score Math Poverty Grade 3 2021-2022'] - demo_df['Average Score Math Poverty Grade 3 2018-2019'])/demo_df['Average Score Math Poverty Grade 3 2018-2019']
poverty1922_3['Reading'] = (demo22['Average Score Reading Poverty Grade 3 2021-2022'] - demo_df['Average Score Reading Poverty Grade 3 2018-2019'])/demo_df['Average Score Reading Poverty Grade 3 2018-2019']
poverty2122_3['Math'] = (demo22['Average Score Math Poverty Grade 3 2021-2022'] - demo_df['Average Score Math Poverty Grade 3 2020-2021'])/demo_df['Average Score Math Poverty Grade 3 2020-2021']
poverty2122_3['Reading'] = (demo22['Average Score Reading Poverty Grade 3 2021-2022'] - demo_df['Average Score Reading Poverty Grade 3 2020-2021'])/demo_df['Average Score Reading Poverty Grade 3 2020-2021']

specialed1921_3['Math'] = (demo_df['Average Score Math Special Ed Grade 3 2020-2021'] - demo_df['Average Score Math Special Ed Grade 3 2018-2019'])/demo_df['Average Score Math Special Ed Grade 3 2018-2019']
specialed1921_3['Reading'] = (demo_df['Average Score Reading Special Ed Grade 3 2020-2021'] - demo_df['Average Score Reading Special Ed Grade 3 2018-2019'])/demo_df['Average Score Reading Special Ed Grade 3 2018-2019']
specialed1922_3['Math'] = (demo22['Average Score Math Special Ed Grade 3 2021-2022'] - demo_df['Average Score Math Special Ed Grade 3 2018-2019'])/demo_df['Average Score Math Special Ed Grade 3 2018-2019']
specialed1922_3['Reading'] = (demo22['Average Score Reading Special Ed Grade 3 2021-2022'] - demo_df['Average Score Reading Special Ed Grade 3 2018-2019'])/demo_df['Average Score Reading Special Ed Grade 3 2018-2019']
specialed2122_3['Math'] = (demo22['Average Score Math Special Ed Grade 3 2021-2022'] - demo_df['Average Score Math Special Ed Grade 3 2020-2021'])/demo_df['Average Score Math Special Ed Grade 3 2020-2021']
specialed2122_3['Reading'] = (demo22['Average Score Reading Special Ed Grade 3 2021-2022'] - demo_df['Average Score Reading Special Ed Grade 3 2020-2021'])/demo_df['Average Score Reading Special Ed Grade 3 2020-2021']

t11921_3['Math'] = (demo_df['Average Score Math T1 Grade 3 2020-2021'] - demo_df['Average Score Math T1 Grade 3 2018-2019'])/demo_df['Average Score Math T1 Grade 3 2018-2019']
t11921_3['Reading'] = (demo_df['Average Score Reading T1 Grade 3 2020-2021'] - demo_df['Average Score Reading T1 Grade 3 2018-2019'])/demo_df['Average Score Reading T1 Grade 3 2018-2019']
t11922_3['Math'] = (demo22['Average Score Math T1 Grade 3 2021-2022'] - demo_df['Average Score Math T1 Grade 3 2018-2019'])/demo_df['Average Score Math T1 Grade 3 2018-2019']
t11922_3['Reading'] = (demo22['Average Score Reading T1 Grade 3 2021-2022'] - demo_df['Average Score Reading T1 Grade 3 2018-2019'])/demo_df['Average Score Reading T1 Grade 3 2018-2019']
t12122_3['Math'] = (demo22['Average Score Math T1 Grade 3 2021-2022'] - demo_df['Average Score Math T1 Grade 3 2020-2021'])/demo_df['Average Score Math T1 Grade 3 2020-2021']
t12122_3['Reading'] = (demo22['Average Score Reading T1 Grade 3 2021-2022'] - demo_df['Average Score Reading T1 Grade 3 2020-2021'])/demo_df['Average Score Reading T1 Grade 3 2020-2021']

with pd.option_context('mode.use_inf_as_na', True):

    #t11921.fillna(0,inplace=True)
    #t11922.fillna(0,inplace=True)
    #t12122.fillna(0,inplace=True)

    asian1921_3.fillna(0,inplace=True)
    all1921_3.fillna(0,inplace=True)
    white1921_3.fillna(0,inplace=True)
    black1921_3.fillna(0,inplace=True)
    freelunch1921_3.fillna(0,inplace=True)
    poverty1921_3.fillna(0,inplace=True)
    hispanic1921_3.fillna(0,inplace=True)
    specialed1921_3.fillna(0,inplace=True)

    asian1922_3.fillna(0,inplace=True)
    all1922_3.fillna(0,inplace=True)
    white1922_3.fillna(0,inplace=True)
    black1922_3.fillna(0,inplace=True)
    freelunch1922_3.fillna(0,inplace=True)
    poverty1922_3.fillna(0,inplace=True)
    hispanic1922_3.fillna(0,inplace=True)
    specialed1922_3.fillna(0,inplace=True)

    asian2122_3.fillna(0,inplace=True)
    all2122_3.fillna(0,inplace=True)
    white2122_3.fillna(0,inplace=True)
    black2122_3.fillna(0,inplace=True)
    freelunch2122_3.fillna(0,inplace=True)
    poverty2122_3.fillna(0,inplace=True)
    hispanic2122_3.fillna(0,inplace=True)
    specialed2122_3.fillna(0,inplace=True)

asian1921_3 = asian1921_3 *100
all1921_3 = all1921_3 *100
white1921_3 = white1921_3*100
black1921_3 = black1921_3*100
freelunch1921_3 = freelunch1921_3*100
poverty1921_3 = poverty1921_3*100
hispanic1921_3 = hispanic1921_3*100
specialed1921_3 = specialed1921_3*100

asian1922_3 = asian1922_3*100
all1922_3 = all1922_3*100
white1922_3 = white1922_3*100
black1922_3 = black1922_3*100
freelunch1922_3 = freelunch1922_3*100
poverty1922_3 = poverty1922_3*100
hispanic1922_3 = hispanic1922_3*100
specialed1922_3 = specialed1922_3*100

asian2122_3 = asian2122_3*100
all2122_3 = all2122_3*100
white2122_3 = white2122_3*100
black2122_3 = black2122_3*100
freelunch2122_3 = freelunch2122_3*100
poverty2122_3 = poverty2122_3*100
hispanic2122_3 = hispanic2122_3*100
specialed2122_3 = specialed2122_3*100

asian1921_3 = asian1921_3.astype(int)
all1921_3 = all1921_3.astype(int)
white1921_3 = white1921_3.astype(int)
black1921_3 = black1921_3.astype(int)
freelunch1921_3 = freelunch1921_3.astype(int)
poverty1921_3 = poverty1921_3.astype(int)
hispanic1921_3 = hispanic1921_3.astype(int)
specialed1921_3 = specialed1921_3.astype(int)

asian1922_3 = asian1922_3.astype(int)
all1922_3 = all1922_3.astype(int)
white1922_3 = white1922_3.astype(int)
black1922_3 = black1922_3.astype(int)
freelunch1922_3 = freelunch1922_3.astype(int)
poverty1922_3 = poverty1922_3.astype(int)
hispanic1922_3 = hispanic1922_3.astype(int)
specialed1922_3 = specialed1922_3.astype(int)

asian2122_3 = asian2122_3.astype(int)
all2122_3 = all2122_3.astype(int)
white2122_3 = white2122_3.astype(int)
black2122_3 = black2122_3.astype(int)
freelunch2122_3 = freelunch2122_3.astype(int)
poverty2122_3 = poverty2122_3.astype(int)
hispanic2122_3 = hispanic2122_3.astype(int)
specialed2122_3 = specialed2122_3.astype(int)

# %%
asian1921_4 = pd.DataFrame()
asian1922_4 = pd.DataFrame()
asian2122_4 = pd.DataFrame()

black1921_4 = pd.DataFrame()
black1922_4 = pd.DataFrame()
black2122_4 = pd.DataFrame()

all1921_4 = pd.DataFrame()
all1922_4 = pd.DataFrame()
all2122_4 = pd.DataFrame()

white1921_4 = pd.DataFrame()
white1922_4 = pd.DataFrame()
white2122_4 = pd.DataFrame()

freelunch1921_4 = pd.DataFrame()
freelunch1922_4 = pd.DataFrame()
freelunch2122_4 = pd.DataFrame()



hispanic1921_4 = pd.DataFrame()
hispanic1922_4 = pd.DataFrame()
hispanic2122_4 = pd.DataFrame()

poverty1921_4 = pd.DataFrame()
poverty1922_4 = pd.DataFrame()
poverty2122_4 = pd.DataFrame()

t11921_4 = pd.DataFrame()
t11922_4 = pd.DataFrame()
t12122_4 = pd.DataFrame()

specialed1921_4 = pd.DataFrame()
specialed1922_4 = pd.DataFrame()
specialed2122_4 = pd.DataFrame()

all1921_4['Math'] = (demo_df['Average Score Math All Grade 4 2020-2021'] - demo_df['Average Score Math All Grade 4 2018-2019'])/demo_df['Average Score Math All Grade 4 2018-2019']
all1921_4['Reading'] = (demo_df['Average Score Reading All Grade 4 2020-2021'] - demo_df['Average Score Reading All Grade 4 2018-2019'])/demo_df['Average Score Reading All Grade 4 2018-2019']
all1922_4['Math'] = (demo22['Average Score Math All Grade 4 2021-2022'] - demo_df['Average Score Math All Grade 4 2018-2019'])/demo_df['Average Score Math All Grade 4 2018-2019']
all1922_4['Reading'] = (demo22['Average Score Reading All Grade 4 2021-2022'] - demo_df['Average Score Reading All Grade 4 2018-2019'])/demo_df['Average Score Reading All Grade 4 2018-2019']
all2122_4['Math'] = (demo22['Average Score Math All Grade 4 2021-2022'] - demo_df['Average Score Math All Grade 4 2020-2021'])/demo_df['Average Score Math All Grade 4 2020-2021']
all2122_4['Reading'] = (demo22['Average Score Reading All Grade 4 2021-2022'] - demo_df['Average Score Reading All Grade 4 2020-2021'])/demo_df['Average Score Reading All Grade 4 2020-2021']

white1921_4['Math'] = (demo_df['Average Score Math White Grade 4 2020-2021'] - demo_df['Average Score Math White Grade 4 2018-2019'])/demo_df['Average Score Math White Grade 4 2018-2019']
white1921_4['Reading'] = (demo_df['Average Score Reading White Grade 4 2020-2021'] - demo_df['Average Score Reading White Grade 4 2018-2019'])/demo_df['Average Score Reading White Grade 4 2018-2019']
white1922_4['Math'] = (demo22['Average Score Math White Grade 4 2021-2022'] - demo_df['Average Score Math White Grade 4 2018-2019'])/demo_df['Average Score Math White Grade 4 2018-2019']
white1922_4['Reading'] = (demo22['Average Score Reading White Grade 4 2021-2022'] - demo_df['Average Score Reading White Grade 4 2018-2019'])/demo_df['Average Score Reading White Grade 4 2018-2019']
white2122_4['Math'] = (demo22['Average Score Math White Grade 4 2021-2022'] - demo_df['Average Score Math White Grade 4 2020-2021'])/demo_df['Average Score Math White Grade 4 2020-2021']
white2122_4['Reading'] = (demo22['Average Score Reading White Grade 4 2021-2022'] - demo_df['Average Score Reading White Grade 4 2020-2021'])/demo_df['Average Score Reading White Grade 4 2020-2021']

hispanic1921_4['Math'] = (demo_df['Average Score Math Hispanic Grade 4 2020-2021'] - demo_df['Average Score Math Hispanic Grade 4 2018-2019'])/demo_df['Average Score Math Hispanic Grade 4 2018-2019']
hispanic1921_4['Reading'] = (demo_df['Average Score Reading Hispanic Grade 4 2020-2021'] - demo_df['Average Score Reading Hispanic Grade 4 2018-2019'])/demo_df['Average Score Reading Hispanic Grade 4 2018-2019']
hispanic1922_4['Math'] = (demo22['Average Score Math Hispanic Grade 4 2021-2022'] - demo_df['Average Score Math Hispanic Grade 4 2018-2019'])/demo_df['Average Score Math Hispanic Grade 4 2018-2019']
hispanic1922_4['Reading'] = (demo22['Average Score Reading Hispanic Grade 4 2021-2022'] - demo_df['Average Score Reading Hispanic Grade 4 2018-2019'])/demo_df['Average Score Reading Hispanic Grade 4 2018-2019']
hispanic2122_4['Math'] = (demo22['Average Score Math Hispanic Grade 4 2021-2022'] - demo_df['Average Score Math Hispanic Grade 4 2020-2021'])/demo_df['Average Score Math Hispanic Grade 4 2020-2021']
hispanic2122_4['Reading'] = (demo22['Average Score Reading Hispanic Grade 4 2021-2022'] - demo_df['Average Score Reading Hispanic Grade 4 2020-2021'])/demo_df['Average Score Reading Hispanic Grade 4 2020-2021']

black1921_4['Math'] = (demo_df['Average Score Math Black Grade 4 2020-2021'] - demo_df['Average Score Math Black Grade 4 2018-2019'])/demo_df['Average Score Math Black Grade 4 2018-2019']
black1921_4['Reading'] = (demo_df['Average Score Reading Black Grade 4 2020-2021'] - demo_df['Average Score Reading Black Grade 4 2018-2019'])/demo_df['Average Score Reading Black Grade 4 2018-2019']
black1922_4['Math'] = (demo22['Average Score Math Black Grade 4 2021-2022'] - demo_df['Average Score Math Black Grade 4 2018-2019'])/demo_df['Average Score Math Black Grade 4 2018-2019']
black1922_4['Reading'] = (demo22['Average Score Reading Black Grade 4 2021-2022'] - demo_df['Average Score Reading Black Grade 4 2018-2019'])/demo_df['Average Score Reading Black Grade 4 2018-2019']
black2122_4['Math'] = (demo22['Average Score Math Black Grade 4 2021-2022'] - demo_df['Average Score Math Black Grade 4 2020-2021'])/demo_df['Average Score Math Black Grade 4 2020-2021']
black2122_4['Reading'] = (demo22['Average Score Reading Black Grade 4 2021-2022'] - demo_df['Average Score Reading Black Grade 4 2020-2021'])/demo_df['Average Score Reading Black Grade 4 2020-2021']

freelunch1921_4['Math'] = (demo_df['Average Score Math Free Lunch Grade 4 2020-2021'] - demo_df['Average Score Math Free Lunch Grade 4 2018-2019'])/demo_df['Average Score Math Free Lunch Grade 4 2018-2019']
freelunch1921_4['Reading'] = (demo_df['Average Score Reading Free Lunch Grade 4 2020-2021'] - demo_df['Average Score Reading Free Lunch Grade 4 2018-2019'])/demo_df['Average Score Reading Free Lunch Grade 4 2018-2019']
freelunch1922_4['Math'] = (demo22['Average Score Math Free Lunch Grade 4 2021-2022'] - demo_df['Average Score Math Free Lunch Grade 4 2018-2019'])/demo_df['Average Score Math Free Lunch Grade 4 2018-2019']
freelunch1922_4['Reading'] = (demo22['Average Score Reading Free Lunch Grade 4 2021-2022'] - demo_df['Average Score Reading Free Lunch Grade 4 2018-2019'])/demo_df['Average Score Reading Free Lunch Grade 4 2018-2019']
freelunch2122_4['Math'] = (demo22['Average Score Math Free Lunch Grade 4 2021-2022'] - demo_df['Average Score Math Free Lunch Grade 4 2020-2021'])/demo_df['Average Score Math Free Lunch Grade 4 2020-2021']
freelunch2122_4['Reading'] = (demo22['Average Score Reading Free Lunch Grade 4 2021-2022'] - demo_df['Average Score Reading Free Lunch Grade 4 2020-2021'])/demo_df['Average Score Reading Free Lunch Grade 4 2020-2021']

poverty1921_4['Math'] = (demo_df['Average Score Math Poverty Grade 4 2020-2021'] - demo_df['Average Score Math Poverty Grade 4 2018-2019'])/demo_df['Average Score Math Poverty Grade 4 2018-2019']
poverty1921_4['Reading'] = (demo_df['Average Score Reading Poverty Grade 4 2020-2021'] - demo_df['Average Score Reading Poverty Grade 4 2018-2019'])/demo_df['Average Score Reading Poverty Grade 4 2018-2019']
poverty1922_4['Math'] = (demo22['Average Score Math Poverty Grade 4 2021-2022'] - demo_df['Average Score Math Poverty Grade 4 2018-2019'])/demo_df['Average Score Math Poverty Grade 4 2018-2019']
poverty1922_4['Reading'] = (demo22['Average Score Reading Poverty Grade 4 2021-2022'] - demo_df['Average Score Reading Poverty Grade 4 2018-2019'])/demo_df['Average Score Reading Poverty Grade 4 2018-2019']
poverty2122_4['Math'] = (demo22['Average Score Math Poverty Grade 4 2021-2022'] - demo_df['Average Score Math Poverty Grade 4 2020-2021'])/demo_df['Average Score Math Poverty Grade 4 2020-2021']
poverty2122_4['Reading'] = (demo22['Average Score Reading Poverty Grade 4 2021-2022'] - demo_df['Average Score Reading Poverty Grade 4 2020-2021'])/demo_df['Average Score Reading Poverty Grade 4 2020-2021']

specialed1921_4['Math'] = (demo_df['Average Score Math Special Ed Grade 4 2020-2021'] - demo_df['Average Score Math Special Ed Grade 4 2018-2019'])/demo_df['Average Score Math Special Ed Grade 4 2018-2019']
specialed1921_4['Reading'] = (demo_df['Average Score Reading Special Ed Grade 4 2020-2021'] - demo_df['Average Score Reading Special Ed Grade 4 2018-2019'])/demo_df['Average Score Reading Special Ed Grade 4 2018-2019']
specialed1922_4['Math'] = (demo22['Average Score Math Special Ed Grade 4 2021-2022'] - demo_df['Average Score Math Special Ed Grade 4 2018-2019'])/demo_df['Average Score Math Special Ed Grade 4 2018-2019']
specialed1922_4['Reading'] = (demo22['Average Score Reading Special Ed Grade 4 2021-2022'] - demo_df['Average Score Reading Special Ed Grade 4 2018-2019'])/demo_df['Average Score Reading Special Ed Grade 4 2018-2019']
specialed2122_4['Math'] = (demo22['Average Score Math Special Ed Grade 4 2021-2022'] - demo_df['Average Score Math Special Ed Grade 4 2020-2021'])/demo_df['Average Score Math Special Ed Grade 4 2020-2021']
specialed2122_4['Reading'] = (demo22['Average Score Reading Special Ed Grade 4 2021-2022'] - demo_df['Average Score Reading Special Ed Grade 4 2020-2021'])/demo_df['Average Score Reading Special Ed Grade 4 2020-2021']

t11921_4['Math'] = (demo_df['Average Score Math T1 Grade 4 2020-2021'] - demo_df['Average Score Math T1 Grade 4 2018-2019'])/demo_df['Average Score Math T1 Grade 4 2018-2019']
t11921_4['Reading'] = (demo_df['Average Score Reading T1 Grade 4 2020-2021'] - demo_df['Average Score Reading T1 Grade 4 2018-2019'])/demo_df['Average Score Reading T1 Grade 4 2018-2019']
t11922_4['Math'] = (demo22['Average Score Math T1 Grade 4 2021-2022'] - demo_df['Average Score Math T1 Grade 4 2018-2019'])/demo_df['Average Score Math T1 Grade 4 2018-2019']
t11922_4['Reading'] = (demo22['Average Score Reading T1 Grade 4 2021-2022'] - demo_df['Average Score Reading T1 Grade 4 2018-2019'])/demo_df['Average Score Reading T1 Grade 4 2018-2019']
t12122_4['Math'] = (demo22['Average Score Math T1 Grade 4 2021-2022'] - demo_df['Average Score Math T1 Grade 4 2020-2021'])/demo_df['Average Score Math T1 Grade 4 2020-2021']
t12122_4['Reading'] = (demo22['Average Score Reading T1 Grade 4 2021-2022'] - demo_df['Average Score Reading T1 Grade 4 2020-2021'])/demo_df['Average Score Reading T1 Grade 4 2020-2021']

with pd.option_context('mode.use_inf_as_na', True):

    #t11921.fillna(0,inplace=True)
    #t11922.fillna(0,inplace=True)
    #t12122.fillna(0,inplace=True)

    asian1921_4.fillna(0,inplace=True)
    all1921_4.fillna(0,inplace=True)
    white1921_4.fillna(0,inplace=True)
    black1921_4.fillna(0,inplace=True)
    freelunch1921_4.fillna(0,inplace=True)
    poverty1921_4.fillna(0,inplace=True)
    hispanic1921_4.fillna(0,inplace=True)
    specialed1921_4.fillna(0,inplace=True)

    asian1922_4.fillna(0,inplace=True)
    all1922_4.fillna(0,inplace=True)
    white1922_4.fillna(0,inplace=True)
    black1922_4.fillna(0,inplace=True)
    freelunch1922_4.fillna(0,inplace=True)
    poverty1922_4.fillna(0,inplace=True)
    hispanic1922_4.fillna(0,inplace=True)
    specialed1922_4.fillna(0,inplace=True)

    asian2122_4.fillna(0,inplace=True)
    all2122_4.fillna(0,inplace=True)
    white2122_4.fillna(0,inplace=True)
    black2122_4.fillna(0,inplace=True)
    freelunch2122_4.fillna(0,inplace=True)
    poverty2122_4.fillna(0,inplace=True)
    hispanic2122_4.fillna(0,inplace=True)
    specialed2122_4.fillna(0,inplace=True)

asian1921_4 = asian1921_4 *100
all1921_4 = all1921_4 *100
white1921_4 = white1921_4*100
black1921_4 = black1921_4*100
freelunch1921_4 = freelunch1921_4*100
poverty1921_4 = poverty1921_4*100
hispanic1921_4 = hispanic1921_4*100
specialed1921_4 = specialed1921_4*100

asian1922_4 = asian1922_4*100
all1922_4 = all1922_4*100
white1922_4 = white1922_4*100
black1922_4 = black1922_4*100
freelunch1922_4 = freelunch1922_4*100
poverty1922_4 = poverty1922_4*100
hispanic1922_4 = hispanic1922_4*100
specialed1922_4 = specialed1922_4*100

asian2122_4 = asian2122_4*100
all2122_4 = all2122_4*100
white2122_4 = white2122_4*100
black2122_4 = black2122_4*100
freelunch2122_4 = freelunch2122_4*100
poverty2122_4 = poverty2122_4*100
hispanic2122_4 = hispanic2122_4*100
specialed2122_4 = specialed2122_4*100

asian1921_4 = asian1921_4.astype(int)
all1921_4 = all1921_4.astype(int)
white1921_4 = white1921_4.astype(int)
black1921_4 = black1921_4.astype(int)
freelunch1921_4 = freelunch1921_4.astype(int)
poverty1921_4 = poverty1921_4.astype(int)
hispanic1921_4 = hispanic1921_4.astype(int)
specialed1921_4 = specialed1921_4.astype(int)

asian1922_4 = asian1922_4.astype(int)
all1922_4 = all1922_4.astype(int)
white1922_4 = white1922_4.astype(int)
black1922_4 = black1922_4.astype(int)
freelunch1922_4 = freelunch1922_4.astype(int)
poverty1922_4 = poverty1922_4.astype(int)
hispanic1922_4 = hispanic1922_4.astype(int)
specialed1922_4 = specialed1922_4.astype(int)

asian2122_4 = asian2122_4.astype(int)
all2122_4 = all2122_4.astype(int)
white2122_4 = white2122_4.astype(int)
black2122_4 = black2122_4.astype(int)
freelunch2122_4 = freelunch2122_4.astype(int)
poverty2122_4 = poverty2122_4.astype(int)
hispanic2122_4 = hispanic2122_4.astype(int)
specialed2122_4 = specialed2122_4.astype(int)

# %%
asian1921_5 = pd.DataFrame()
asian1922_5 = pd.DataFrame()
asian2122_5 = pd.DataFrame()

black1921_5 = pd.DataFrame()
black1922_5 = pd.DataFrame()
black2122_5 = pd.DataFrame()

all1921_5 = pd.DataFrame()
all1922_5 = pd.DataFrame()
all2122_5 = pd.DataFrame()

white1921_5 = pd.DataFrame()
white1922_5 = pd.DataFrame()
white2122_5 = pd.DataFrame()

freelunch1921_5 = pd.DataFrame()
freelunch1922_5 = pd.DataFrame()
freelunch2122_5 = pd.DataFrame()



hispanic1921_5 = pd.DataFrame()
hispanic1922_5 = pd.DataFrame()
hispanic2122_5 = pd.DataFrame()

poverty1921_5 = pd.DataFrame()
poverty1922_5 = pd.DataFrame()
poverty2122_5 = pd.DataFrame()

t11921_5 = pd.DataFrame()
t11922_5 = pd.DataFrame()
t12122_5 = pd.DataFrame()

specialed1921_5 = pd.DataFrame()
specialed1922_5 = pd.DataFrame()
specialed2122_5 = pd.DataFrame()

all1921_5['Math'] = (demo_df['Average Score Math All Grade 5 2020-2021'] - demo_df['Average Score Math All Grade 5 2018-2019'])/demo_df['Average Score Math All Grade 5 2018-2019']
all1921_5['Reading'] = (demo_df['Average Score Reading All Grade 5 2020-2021'] - demo_df['Average Score Reading All Grade 5 2018-2019'])/demo_df['Average Score Reading All Grade 5 2018-2019']
all1922_5['Math'] = (demo22['Average Score Math All Grade 5 2021-2022'] - demo_df['Average Score Math All Grade 5 2018-2019'])/demo_df['Average Score Math All Grade 5 2018-2019']
all1922_5['Reading'] = (demo22['Average Score Reading All Grade 5 2021-2022'] - demo_df['Average Score Reading All Grade 5 2018-2019'])/demo_df['Average Score Reading All Grade 5 2018-2019']
all2122_5['Math'] = (demo22['Average Score Math All Grade 5 2021-2022'] - demo_df['Average Score Math All Grade 5 2020-2021'])/demo_df['Average Score Math All Grade 5 2020-2021']
all2122_5['Reading'] = (demo22['Average Score Reading All Grade 5 2021-2022'] - demo_df['Average Score Reading All Grade 5 2020-2021'])/demo_df['Average Score Reading All Grade 5 2020-2021']

white1921_5['Math'] = (demo_df['Average Score Math White Grade 5 2020-2021'] - demo_df['Average Score Math White Grade 5 2018-2019'])/demo_df['Average Score Math White Grade 5 2018-2019']
white1921_5['Reading'] = (demo_df['Average Score Reading White Grade 5 2020-2021'] - demo_df['Average Score Reading White Grade 5 2018-2019'])/demo_df['Average Score Reading White Grade 5 2018-2019']
white1922_5['Math'] = (demo22['Average Score Math White Grade 5 2021-2022'] - demo_df['Average Score Math White Grade 5 2018-2019'])/demo_df['Average Score Math White Grade 5 2018-2019']
white1922_5['Reading'] = (demo22['Average Score Reading White Grade 5 2021-2022'] - demo_df['Average Score Reading White Grade 5 2018-2019'])/demo_df['Average Score Reading White Grade 5 2018-2019']
white2122_5['Math'] = (demo22['Average Score Math White Grade 5 2021-2022'] - demo_df['Average Score Math White Grade 5 2020-2021'])/demo_df['Average Score Math White Grade 5 2020-2021']
white2122_5['Reading'] = (demo22['Average Score Reading White Grade 5 2021-2022'] - demo_df['Average Score Reading White Grade 5 2020-2021'])/demo_df['Average Score Reading White Grade 5 2020-2021']

hispanic1921_5['Math'] = (demo_df['Average Score Math Hispanic Grade 5 2020-2021'] - demo_df['Average Score Math Hispanic Grade 5 2018-2019'])/demo_df['Average Score Math Hispanic Grade 5 2018-2019']
hispanic1921_5['Reading'] = (demo_df['Average Score Reading Hispanic Grade 5 2020-2021'] - demo_df['Average Score Reading Hispanic Grade 5 2018-2019'])/demo_df['Average Score Reading Hispanic Grade 5 2018-2019']
hispanic1922_5['Math'] = (demo22['Average Score Math Hispanic Grade 5 2021-2022'] - demo_df['Average Score Math Hispanic Grade 5 2018-2019'])/demo_df['Average Score Math Hispanic Grade 5 2018-2019']
hispanic1922_5['Reading'] = (demo22['Average Score Reading Hispanic Grade 5 2021-2022'] - demo_df['Average Score Reading Hispanic Grade 5 2018-2019'])/demo_df['Average Score Reading Hispanic Grade 5 2018-2019']
hispanic2122_5['Math'] = (demo22['Average Score Math Hispanic Grade 5 2021-2022'] - demo_df['Average Score Math Hispanic Grade 5 2020-2021'])/demo_df['Average Score Math Hispanic Grade 5 2020-2021']
hispanic2122_5['Reading'] = (demo22['Average Score Reading Hispanic Grade 5 2021-2022'] - demo_df['Average Score Reading Hispanic Grade 5 2020-2021'])/demo_df['Average Score Reading Hispanic Grade 5 2020-2021']

black1921_5['Math'] = (demo_df['Average Score Math Black Grade 5 2020-2021'] - demo_df['Average Score Math Black Grade 5 2018-2019'])/demo_df['Average Score Math Black Grade 5 2018-2019']
black1921_5['Reading'] = (demo_df['Average Score Reading Black Grade 5 2020-2021'] - demo_df['Average Score Reading Black Grade 5 2018-2019'])/demo_df['Average Score Reading Black Grade 5 2018-2019']
black1922_5['Math'] = (demo22['Average Score Math Black Grade 5 2021-2022'] - demo_df['Average Score Math Black Grade 5 2018-2019'])/demo_df['Average Score Math Black Grade 5 2018-2019']
black1922_5['Reading'] = (demo22['Average Score Reading Black Grade 5 2021-2022'] - demo_df['Average Score Reading Black Grade 5 2018-2019'])/demo_df['Average Score Reading Black Grade 5 2018-2019']
black2122_5['Math'] = (demo22['Average Score Math Black Grade 5 2021-2022'] - demo_df['Average Score Math Black Grade 5 2020-2021'])/demo_df['Average Score Math Black Grade 5 2020-2021']
black2122_5['Reading'] = (demo22['Average Score Reading Black Grade 5 2021-2022'] - demo_df['Average Score Reading Black Grade 5 2020-2021'])/demo_df['Average Score Reading Black Grade 5 2020-2021']

freelunch1921_5['Math'] = (demo_df['Average Score Math Free Lunch Grade 5 2020-2021'] - demo_df['Average Score Math Free Lunch Grade 5 2018-2019'])/demo_df['Average Score Math Free Lunch Grade 5 2018-2019']
freelunch1921_5['Reading'] = (demo_df['Average Score Reading Free Lunch Grade 5 2020-2021'] - demo_df['Average Score Reading Free Lunch Grade 5 2018-2019'])/demo_df['Average Score Reading Free Lunch Grade 5 2018-2019']
freelunch1922_5['Math'] = (demo22['Average Score Math Free Lunch Grade 5 2021-2022'] - demo_df['Average Score Math Free Lunch Grade 5 2018-2019'])/demo_df['Average Score Math Free Lunch Grade 5 2018-2019']
freelunch1922_5['Reading'] = (demo22['Average Score Reading Free Lunch Grade 5 2021-2022'] - demo_df['Average Score Reading Free Lunch Grade 5 2018-2019'])/demo_df['Average Score Reading Free Lunch Grade 5 2018-2019']
freelunch2122_5['Math'] = (demo22['Average Score Math Free Lunch Grade 5 2021-2022'] - demo_df['Average Score Math Free Lunch Grade 5 2020-2021'])/demo_df['Average Score Math Free Lunch Grade 5 2020-2021']
freelunch2122_5['Reading'] = (demo22['Average Score Reading Free Lunch Grade 5 2021-2022'] - demo_df['Average Score Reading Free Lunch Grade 5 2020-2021'])/demo_df['Average Score Reading Free Lunch Grade 5 2020-2021']

poverty1921_5['Math'] = (demo_df['Average Score Math Poverty Grade 5 2020-2021'] - demo_df['Average Score Math Poverty Grade 5 2018-2019'])/demo_df['Average Score Math Poverty Grade 5 2018-2019']
poverty1921_5['Reading'] = (demo_df['Average Score Reading Poverty Grade 5 2020-2021'] - demo_df['Average Score Reading Poverty Grade 5 2018-2019'])/demo_df['Average Score Reading Poverty Grade 5 2018-2019']
poverty1922_5['Math'] = (demo22['Average Score Math Poverty Grade 5 2021-2022'] - demo_df['Average Score Math Poverty Grade 5 2018-2019'])/demo_df['Average Score Math Poverty Grade 5 2018-2019']
poverty1922_5['Reading'] = (demo22['Average Score Reading Poverty Grade 5 2021-2022'] - demo_df['Average Score Reading Poverty Grade 5 2018-2019'])/demo_df['Average Score Reading Poverty Grade 5 2018-2019']
poverty2122_5['Math'] = (demo22['Average Score Math Poverty Grade 5 2021-2022'] - demo_df['Average Score Math Poverty Grade 5 2020-2021'])/demo_df['Average Score Math Poverty Grade 5 2020-2021']
poverty2122_5['Reading'] = (demo22['Average Score Reading Poverty Grade 5 2021-2022'] - demo_df['Average Score Reading Poverty Grade 5 2020-2021'])/demo_df['Average Score Reading Poverty Grade 5 2020-2021']

specialed1921_5['Math'] = (demo_df['Average Score Math Special Ed Grade 5 2020-2021'] - demo_df['Average Score Math Special Ed Grade 5 2018-2019'])/demo_df['Average Score Math Special Ed Grade 5 2018-2019']
specialed1921_5['Reading'] = (demo_df['Average Score Reading Special Ed Grade 5 2020-2021'] - demo_df['Average Score Reading Special Ed Grade 5 2018-2019'])/demo_df['Average Score Reading Special Ed Grade 5 2018-2019']
specialed1922_5['Math'] = (demo22['Average Score Math Special Ed Grade 5 2021-2022'] - demo_df['Average Score Math Special Ed Grade 5 2018-2019'])/demo_df['Average Score Math Special Ed Grade 5 2018-2019']
specialed1922_5['Reading'] = (demo22['Average Score Reading Special Ed Grade 5 2021-2022'] - demo_df['Average Score Reading Special Ed Grade 5 2018-2019'])/demo_df['Average Score Reading Special Ed Grade 5 2018-2019']
specialed2122_5['Math'] = (demo22['Average Score Math Special Ed Grade 5 2021-2022'] - demo_df['Average Score Math Special Ed Grade 5 2020-2021'])/demo_df['Average Score Math Special Ed Grade 5 2020-2021']
specialed2122_5['Reading'] = (demo22['Average Score Reading Special Ed Grade 5 2021-2022'] - demo_df['Average Score Reading Special Ed Grade 5 2020-2021'])/demo_df['Average Score Reading Special Ed Grade 5 2020-2021']

t11921_5['Math'] = (demo_df['Average Score Math T1 Grade 5 2020-2021'] - demo_df['Average Score Math T1 Grade 5 2018-2019'])/demo_df['Average Score Math T1 Grade 5 2018-2019']
t11921_5['Reading'] = (demo_df['Average Score Reading T1 Grade 5 2020-2021'] - demo_df['Average Score Reading T1 Grade 5 2018-2019'])/demo_df['Average Score Reading T1 Grade 5 2018-2019']
t11922_5['Math'] = (demo22['Average Score Math T1 Grade 5 2021-2022'] - demo_df['Average Score Math T1 Grade 5 2018-2019'])/demo_df['Average Score Math T1 Grade 5 2018-2019']
t11922_5['Reading'] = (demo22['Average Score Reading T1 Grade 5 2021-2022'] - demo_df['Average Score Reading T1 Grade 5 2018-2019'])/demo_df['Average Score Reading T1 Grade 5 2018-2019']
t12122_5['Math'] = (demo22['Average Score Math T1 Grade 5 2021-2022'] - demo_df['Average Score Math T1 Grade 5 2020-2021'])/demo_df['Average Score Math T1 Grade 5 2020-2021']
t12122_5['Reading'] = (demo22['Average Score Reading T1 Grade 5 2021-2022'] - demo_df['Average Score Reading T1 Grade 5 2020-2021'])/demo_df['Average Score Reading T1 Grade 5 2020-2021']

with pd.option_context('mode.use_inf_as_na', True):

#    t11921.fillna(0,inplace=True)
 #   t11922.fillna(0,inplace=True)
  #  t12122.fillna(0,inplace=True)

    asian1921_5.fillna(0,inplace=True)
    all1921_5.fillna(0,inplace=True)
    white1921_5.fillna(0,inplace=True)
    black1921_5.fillna(0,inplace=True)
    freelunch1921_5.fillna(0,inplace=True)
    poverty1921_5.fillna(0,inplace=True)
    hispanic1921_5.fillna(0,inplace=True)
    specialed1921_5.fillna(0,inplace=True)

    asian1922_5.fillna(0,inplace=True)
    all1922_5.fillna(0,inplace=True)
    white1922_5.fillna(0,inplace=True)
    black1922_5.fillna(0,inplace=True)
    freelunch1922_5.fillna(0,inplace=True)
    poverty1922_5.fillna(0,inplace=True)
    hispanic1922_5.fillna(0,inplace=True)
    specialed1922_5.fillna(0,inplace=True)

    asian2122_5.fillna(0,inplace=True)
    all2122_5.fillna(0,inplace=True)
    white2122_5.fillna(0,inplace=True)
    black2122_5.fillna(0,inplace=True)
    freelunch2122_5.fillna(0,inplace=True)
    poverty2122_5.fillna(0,inplace=True)
    hispanic2122_5.fillna(0,inplace=True)
    specialed2122_5.fillna(0,inplace=True)

asian1921_5 = asian1921_5 *100
all1921_5 = all1921_5 *100
white1921_5 = white1921_5*100
black1921_5 = black1921_5*100
freelunch1921_5 = freelunch1921_5*100
poverty1921_5 = poverty1921_5*100
hispanic1921_5 = hispanic1921_5*100
specialed1921_5 = specialed1921_5*100

asian1922_5 = asian1922_5*100
all1922_5 = all1922_5*100
white1922_5 = white1922_5*100
black1922_5 = black1922_5*100
freelunch1922_5 = freelunch1922_5*100
poverty1922_5 = poverty1922_5*100
hispanic1922_5 = hispanic1922_5*100
specialed1922_5 = specialed1922_5*100

asian2122_5 = asian2122_5*100
all2122_5 = all2122_5*100
white2122_5 = white2122_5*100
black2122_5 = black2122_5*100
freelunch2122_5 = freelunch2122_5*100
poverty2122_5 = poverty2122_5*100
hispanic2122_5 = hispanic2122_5*100
specialed2122_5 = specialed2122_5*100

asian1921_5 = asian1921_5.astype(int)
all1921_5 = all1921_5.astype(int)
white1921_5 = white1921_5.astype(int)
black1921_5 = black1921_5.astype(int)
freelunch1921_5 = freelunch1921_5.astype(int)
poverty1921_5 = poverty1921_5.astype(int)
hispanic1921_5 = hispanic1921_5.astype(int)
specialed1921_5 = specialed1921_5.astype(int)

asian1922_5 = asian1922_5.astype(int)
all1922_5 = all1922_5.astype(int)
white1922_5 = white1922_5.astype(int)
black1922_5 = black1922_5.astype(int)
freelunch1922_5 = freelunch1922_5.astype(int)
poverty1922_5 = poverty1922_5.astype(int)
hispanic1922_5 = hispanic1922_5.astype(int)
specialed1922_5 = specialed1922_5.astype(int)

asian2122_5 = asian2122_5.astype(int)
all2122_5 = all2122_5.astype(int)
white2122_5 = white2122_5.astype(int)
black2122_5 = black2122_5.astype(int)
freelunch2122_5 = freelunch2122_5.astype(int)
poverty2122_5 = poverty2122_5.astype(int)
hispanic2122_5 = hispanic2122_5.astype(int)
specialed2122_5 = specialed2122_5.astype(int)

# %%
asian1921_6 = pd.DataFrame()
asian1922_6 = pd.DataFrame()
asian2122_6 = pd.DataFrame()

black1921_6 = pd.DataFrame()
black1922_6 = pd.DataFrame()
black2122_6 = pd.DataFrame()

all1921_6 = pd.DataFrame()
all1922_6 = pd.DataFrame()
all2122_6 = pd.DataFrame()

white1921_6 = pd.DataFrame()
white1922_6 = pd.DataFrame()
white2122_6 = pd.DataFrame()

freelunch1921_6 = pd.DataFrame()
freelunch1922_6 = pd.DataFrame()
freelunch2122_6 = pd.DataFrame()



hispanic1921_6 = pd.DataFrame()
hispanic1922_6 = pd.DataFrame()
hispanic2122_6 = pd.DataFrame()

poverty1921_6 = pd.DataFrame()
poverty1922_6 = pd.DataFrame()
poverty2122_6 = pd.DataFrame()

t11921_6 = pd.DataFrame()
t11922_6 = pd.DataFrame()
t12122_6 = pd.DataFrame()

specialed1921_6 = pd.DataFrame()
specialed1922_6 = pd.DataFrame()
specialed2122_6 = pd.DataFrame()

all1921_6['Math'] = (demo_df['Average Score Math All Grade 6 2020-2021'] - demo_df['Average Score Math All Grade 6 2018-2019'])/demo_df['Average Score Math All Grade 6 2018-2019']
all1921_6['Reading'] = (demo_df['Average Score Reading All Grade 6 2020-2021'] - demo_df['Average Score Reading All Grade 6 2018-2019'])/demo_df['Average Score Reading All Grade 6 2018-2019']
all1922_6['Math'] = (demo22['Average Score Math All Grade 6 2021-2022'] - demo_df['Average Score Math All Grade 6 2018-2019'])/demo_df['Average Score Math All Grade 6 2018-2019']
all1922_6['Reading'] = (demo22['Average Score Reading All Grade 6 2021-2022'] - demo_df['Average Score Reading All Grade 6 2018-2019'])/demo_df['Average Score Reading All Grade 6 2018-2019']
all2122_6['Math'] = (demo22['Average Score Math All Grade 6 2021-2022'] - demo_df['Average Score Math All Grade 6 2020-2021'])/demo_df['Average Score Math All Grade 6 2020-2021']
all2122_6['Reading'] = (demo22['Average Score Reading All Grade 6 2021-2022'] - demo_df['Average Score Reading All Grade 6 2020-2021'])/demo_df['Average Score Reading All Grade 6 2020-2021']

white1921_6['Math'] = (demo_df['Average Score Math White Grade 6 2020-2021'] - demo_df['Average Score Math White Grade 6 2018-2019'])/demo_df['Average Score Math White Grade 6 2018-2019']
white1921_6['Reading'] = (demo_df['Average Score Reading White Grade 6 2020-2021'] - demo_df['Average Score Reading White Grade 6 2018-2019'])/demo_df['Average Score Reading White Grade 6 2018-2019']
white1922_6['Math'] = (demo22['Average Score Math White Grade 6 2021-2022'] - demo_df['Average Score Math White Grade 6 2018-2019'])/demo_df['Average Score Math White Grade 6 2018-2019']
white1922_6['Reading'] = (demo22['Average Score Reading White Grade 6 2021-2022'] - demo_df['Average Score Reading White Grade 6 2018-2019'])/demo_df['Average Score Reading White Grade 6 2018-2019']
white2122_6['Math'] = (demo22['Average Score Math White Grade 6 2021-2022'] - demo_df['Average Score Math White Grade 6 2020-2021'])/demo_df['Average Score Math White Grade 6 2020-2021']
white2122_6['Reading'] = (demo22['Average Score Reading White Grade 6 2021-2022'] - demo_df['Average Score Reading White Grade 6 2020-2021'])/demo_df['Average Score Reading White Grade 6 2020-2021']

hispanic1921_6['Math'] = (demo_df['Average Score Math Hispanic Grade 6 2020-2021'] - demo_df['Average Score Math Hispanic Grade 6 2018-2019'])/demo_df['Average Score Math Hispanic Grade 6 2018-2019']
hispanic1921_6['Reading'] = (demo_df['Average Score Reading Hispanic Grade 6 2020-2021'] - demo_df['Average Score Reading Hispanic Grade 6 2018-2019'])/demo_df['Average Score Reading Hispanic Grade 6 2018-2019']
hispanic1922_6['Math'] = (demo22['Average Score Math Hispanic Grade 6 2021-2022'] - demo_df['Average Score Math Hispanic Grade 6 2018-2019'])/demo_df['Average Score Math Hispanic Grade 6 2018-2019']
hispanic1922_6['Reading'] = (demo22['Average Score Reading Hispanic Grade 6 2021-2022'] - demo_df['Average Score Reading Hispanic Grade 6 2018-2019'])/demo_df['Average Score Reading Hispanic Grade 6 2018-2019']
hispanic2122_6['Math'] = (demo22['Average Score Math Hispanic Grade 6 2021-2022'] - demo_df['Average Score Math Hispanic Grade 6 2020-2021'])/demo_df['Average Score Math Hispanic Grade 6 2020-2021']
hispanic2122_6['Reading'] = (demo22['Average Score Reading Hispanic Grade 6 2021-2022'] - demo_df['Average Score Reading Hispanic Grade 6 2020-2021'])/demo_df['Average Score Reading Hispanic Grade 6 2020-2021']

black1921_6['Math'] = (demo_df['Average Score Math Black Grade 6 2020-2021'] - demo_df['Average Score Math Black Grade 6 2018-2019'])/demo_df['Average Score Math Black Grade 6 2018-2019']
black1921_6['Reading'] = (demo_df['Average Score Reading Black Grade 6 2020-2021'] - demo_df['Average Score Reading Black Grade 6 2018-2019'])/demo_df['Average Score Reading Black Grade 6 2018-2019']
black1922_6['Math'] = (demo22['Average Score Math Black Grade 6 2021-2022'] - demo_df['Average Score Math Black Grade 6 2018-2019'])/demo_df['Average Score Math Black Grade 6 2018-2019']
black1922_6['Reading'] = (demo22['Average Score Reading Black Grade 6 2021-2022'] - demo_df['Average Score Reading Black Grade 6 2018-2019'])/demo_df['Average Score Reading Black Grade 6 2018-2019']
black2122_6['Math'] = (demo22['Average Score Math Black Grade 6 2021-2022'] - demo_df['Average Score Math Black Grade 6 2020-2021'])/demo_df['Average Score Math Black Grade 6 2020-2021']
black2122_6['Reading'] = (demo22['Average Score Reading Black Grade 6 2021-2022'] - demo_df['Average Score Reading Black Grade 6 2020-2021'])/demo_df['Average Score Reading Black Grade 6 2020-2021']

freelunch1921_6['Math'] = (demo_df['Average Score Math Free Lunch Grade 6 2020-2021'] - demo_df['Average Score Math Free Lunch Grade 6 2018-2019'])/demo_df['Average Score Math Free Lunch Grade 6 2018-2019']
freelunch1921_6['Reading'] = (demo_df['Average Score Reading Free Lunch Grade 6 2020-2021'] - demo_df['Average Score Reading Free Lunch Grade 6 2018-2019'])/demo_df['Average Score Reading Free Lunch Grade 6 2018-2019']
freelunch1922_6['Math'] = (demo22['Average Score Math Free Lunch Grade 6 2021-2022'] - demo_df['Average Score Math Free Lunch Grade 6 2018-2019'])/demo_df['Average Score Math Free Lunch Grade 6 2018-2019']
freelunch1922_6['Reading'] = (demo22['Average Score Reading Free Lunch Grade 6 2021-2022'] - demo_df['Average Score Reading Free Lunch Grade 6 2018-2019'])/demo_df['Average Score Reading Free Lunch Grade 6 2018-2019']
freelunch2122_6['Math'] = (demo22['Average Score Math Free Lunch Grade 6 2021-2022'] - demo_df['Average Score Math Free Lunch Grade 6 2020-2021'])/demo_df['Average Score Math Free Lunch Grade 6 2020-2021']
freelunch2122_6['Reading'] = (demo22['Average Score Reading Free Lunch Grade 6 2021-2022'] - demo_df['Average Score Reading Free Lunch Grade 6 2020-2021'])/demo_df['Average Score Reading Free Lunch Grade 6 2020-2021']

poverty1921_6['Math'] = (demo_df['Average Score Math Poverty Grade 6 2020-2021'] - demo_df['Average Score Math Poverty Grade 6 2018-2019'])/demo_df['Average Score Math Poverty Grade 6 2018-2019']
poverty1921_6['Reading'] = (demo_df['Average Score Reading Poverty Grade 6 2020-2021'] - demo_df['Average Score Reading Poverty Grade 6 2018-2019'])/demo_df['Average Score Reading Poverty Grade 6 2018-2019']
poverty1922_6['Math'] = (demo22['Average Score Math Poverty Grade 6 2021-2022'] - demo_df['Average Score Math Poverty Grade 6 2018-2019'])/demo_df['Average Score Math Poverty Grade 6 2018-2019']
poverty1922_6['Reading'] = (demo22['Average Score Reading Poverty Grade 6 2021-2022'] - demo_df['Average Score Reading Poverty Grade 6 2018-2019'])/demo_df['Average Score Reading Poverty Grade 6 2018-2019']
poverty2122_6['Math'] = (demo22['Average Score Math Poverty Grade 6 2021-2022'] - demo_df['Average Score Math Poverty Grade 6 2020-2021'])/demo_df['Average Score Math Poverty Grade 6 2020-2021']
poverty2122_6['Reading'] = (demo22['Average Score Reading Poverty Grade 6 2021-2022'] - demo_df['Average Score Reading Poverty Grade 6 2020-2021'])/demo_df['Average Score Reading Poverty Grade 6 2020-2021']

specialed1921_6['Math'] = (demo_df['Average Score Math Special Ed Grade 6 2020-2021'] - demo_df['Average Score Math Special Ed Grade 6 2018-2019'])/demo_df['Average Score Math Special Ed Grade 6 2018-2019']
specialed1921_6['Reading'] = (demo_df['Average Score Reading Special Ed Grade 6 2020-2021'] - demo_df['Average Score Reading Special Ed Grade 6 2018-2019'])/demo_df['Average Score Reading Special Ed Grade 6 2018-2019']
specialed1922_6['Math'] = (demo22['Average Score Math Special Ed Grade 6 2021-2022'] - demo_df['Average Score Math Special Ed Grade 6 2018-2019'])/demo_df['Average Score Math Special Ed Grade 6 2018-2019']
specialed1922_6['Reading'] = (demo22['Average Score Reading Special Ed Grade 6 2021-2022'] - demo_df['Average Score Reading Special Ed Grade 6 2018-2019'])/demo_df['Average Score Reading Special Ed Grade 6 2018-2019']
specialed2122_6['Math'] = (demo22['Average Score Math Special Ed Grade 6 2021-2022'] - demo_df['Average Score Math Special Ed Grade 6 2020-2021'])/demo_df['Average Score Math Special Ed Grade 6 2020-2021']
specialed2122_6['Reading'] = (demo22['Average Score Reading Special Ed Grade 6 2021-2022'] - demo_df['Average Score Reading Special Ed Grade 6 2020-2021'])/demo_df['Average Score Reading Special Ed Grade 6 2020-2021']

t11921_6['Math'] = (demo_df['Average Score Math T1 Grade 6 2020-2021'] - demo_df['Average Score Math T1 Grade 6 2018-2019'])/demo_df['Average Score Math T1 Grade 6 2018-2019']
t11921_6['Reading'] = (demo_df['Average Score Reading T1 Grade 6 2020-2021'] - demo_df['Average Score Reading T1 Grade 6 2018-2019'])/demo_df['Average Score Reading T1 Grade 6 2018-2019']
t11922_6['Math'] = (demo22['Average Score Math T1 Grade 6 2021-2022'] - demo_df['Average Score Math T1 Grade 6 2018-2019'])/demo_df['Average Score Math T1 Grade 6 2018-2019']
t11922_6['Reading'] = (demo22['Average Score Reading T1 Grade 6 2021-2022'] - demo_df['Average Score Reading T1 Grade 6 2018-2019'])/demo_df['Average Score Reading T1 Grade 6 2018-2019']
t12122_6['Math'] = (demo22['Average Score Math T1 Grade 6 2021-2022'] - demo_df['Average Score Math T1 Grade 6 2020-2021'])/demo_df['Average Score Math T1 Grade 6 2020-2021']
t12122_6['Reading'] = (demo22['Average Score Reading T1 Grade 6 2021-2022'] - demo_df['Average Score Reading T1 Grade 6 2020-2021'])/demo_df['Average Score Reading T1 Grade 6 2020-2021']

with pd.option_context('mode.use_inf_as_na', True):

  #  t11921.fillna(0,inplace=True)
  # t11922.fillna(0,inplace=True)
  # t12122.fillna(0,inplace=True)

    asian1921_6.fillna(0,inplace=True)
    all1921_6.fillna(0,inplace=True)
    white1921_6.fillna(0,inplace=True)
    black1921_6.fillna(0,inplace=True)
    freelunch1921_6.fillna(0,inplace=True)
    poverty1921_6.fillna(0,inplace=True)
    hispanic1921_6.fillna(0,inplace=True)
    specialed1921_6.fillna(0,inplace=True)

    asian1922_6.fillna(0,inplace=True)
    all1922_6.fillna(0,inplace=True)
    white1922_6.fillna(0,inplace=True)
    black1922_6.fillna(0,inplace=True)
    freelunch1922_6.fillna(0,inplace=True)
    poverty1922_6.fillna(0,inplace=True)
    hispanic1922_6.fillna(0,inplace=True)
    specialed1922_6.fillna(0,inplace=True)

    asian2122_6.fillna(0,inplace=True)
    all2122_6.fillna(0,inplace=True)
    white2122_6.fillna(0,inplace=True)
    black2122_6.fillna(0,inplace=True)
    freelunch2122_6.fillna(0,inplace=True)
    poverty2122_6.fillna(0,inplace=True)
    hispanic2122_6.fillna(0,inplace=True)
    specialed2122_6.fillna(0,inplace=True)

asian1921_6 = asian1921_6 *100
all1921_6 = all1921_6 *100
white1921_6 = white1921_6*100
black1921_6 = black1921_6*100
freelunch1921_6 = freelunch1921_6*100
poverty1921_6 = poverty1921_6*100
hispanic1921_6 = hispanic1921_6*100
specialed1921_6 = specialed1921_6*100

asian1922_6 = asian1922_6*100
all1922_6 = all1922_6*100
white1922_6 = white1922_6*100
black1922_6 = black1922_6*100
freelunch1922_6 = freelunch1922_6*100
poverty1922_6 = poverty1922_6*100
hispanic1922_6 = hispanic1922_6*100
specialed1922_6 = specialed1922_6*100

asian2122_6 = asian2122_6*100
all2122_6 = all2122_6*100
white2122_6 = white2122_6*100
black2122_6 = black2122_6*100
freelunch2122_6 = freelunch2122_6*100
poverty2122_6 = poverty2122_6*100
hispanic2122_6 = hispanic2122_6*100
specialed2122_6 = specialed2122_6*100

asian1921_6 = asian1921_6.astype(int)
all1921_6 = all1921_6.astype(int)
white1921_6 = white1921_6.astype(int)
black1921_6 = black1921_6.astype(int)
freelunch1921_6 = freelunch1921_6.astype(int)
poverty1921_6 = poverty1921_6.astype(int)
hispanic1921_6 = hispanic1921_6.astype(int)
specialed1921_6 = specialed1921_6.astype(int)

asian1922_6 = asian1922_6.astype(int)
all1922_6 = all1922_6.astype(int)
white1922_6 = white1922_6.astype(int)
black1922_6 = black1922_6.astype(int)
freelunch1922_6 = freelunch1922_6.astype(int)
poverty1922_6 = poverty1922_6.astype(int)
hispanic1922_6 = hispanic1922_6.astype(int)
specialed1922_6 = specialed1922_6.astype(int)

asian2122_6 = asian2122_6.astype(int)
all2122_6 = all2122_6.astype(int)
white2122_6 = white2122_6.astype(int)
black2122_6 = black2122_6.astype(int)
freelunch2122_6 = freelunch2122_6.astype(int)
poverty2122_6 = poverty2122_6.astype(int)
hispanic2122_6 = hispanic2122_6.astype(int)
specialed2122_6 = specialed2122_6.astype(int)

# %%
asian1921_7 = pd.DataFrame()
asian1922_7 = pd.DataFrame()
asian2122_7 = pd.DataFrame()

black1921_7 = pd.DataFrame()
black1922_7 = pd.DataFrame()
black2122_7 = pd.DataFrame()

all1921_7 = pd.DataFrame()
all1922_7 = pd.DataFrame()
all2122_7 = pd.DataFrame()

white1921_7 = pd.DataFrame()
white1922_7 = pd.DataFrame()
white2122_7 = pd.DataFrame()

freelunch1921_7 = pd.DataFrame()
freelunch1922_7 = pd.DataFrame()
freelunch2122_7 = pd.DataFrame()



hispanic1921_7 = pd.DataFrame()
hispanic1922_7 = pd.DataFrame()
hispanic2122_7 = pd.DataFrame()

poverty1921_7 = pd.DataFrame()
poverty1922_7 = pd.DataFrame()
poverty2122_7 = pd.DataFrame()

t11921_7 = pd.DataFrame()
t11922_7 = pd.DataFrame()
t12122_7 = pd.DataFrame()

specialed1921_7 = pd.DataFrame()
specialed1922_7 = pd.DataFrame()
specialed2122_7 = pd.DataFrame()

all1921_7['Math'] = (demo_df['Average Score Math All Grade 7 2020-2021'] - demo_df['Average Score Math All Grade 7 2018-2019'])/demo_df['Average Score Math All Grade 7 2018-2019']
all1921_7['Reading'] = (demo_df['Average Score Reading All Grade 7 2020-2021'] - demo_df['Average Score Reading All Grade 7 2018-2019'])/demo_df['Average Score Reading All Grade 7 2018-2019']
all1922_7['Math'] = (demo22['Average Score Math All Grade 7 2021-2022'] - demo_df['Average Score Math All Grade 7 2018-2019'])/demo_df['Average Score Math All Grade 7 2018-2019']
all1922_7['Reading'] = (demo22['Average Score Reading All Grade 7 2021-2022'] - demo_df['Average Score Reading All Grade 7 2018-2019'])/demo_df['Average Score Reading All Grade 7 2018-2019']
all2122_7['Math'] = (demo22['Average Score Math All Grade 7 2021-2022'] - demo_df['Average Score Math All Grade 7 2020-2021'])/demo_df['Average Score Math All Grade 7 2020-2021']
all2122_7['Reading'] = (demo22['Average Score Reading All Grade 7 2021-2022'] - demo_df['Average Score Reading All Grade 7 2020-2021'])/demo_df['Average Score Reading All Grade 7 2020-2021']

white1921_7['Math'] = (demo_df['Average Score Math White Grade 7 2020-2021'] - demo_df['Average Score Math White Grade 7 2018-2019'])/demo_df['Average Score Math White Grade 7 2018-2019']
white1921_7['Reading'] = (demo_df['Average Score Reading White Grade 7 2020-2021'] - demo_df['Average Score Reading White Grade 7 2018-2019'])/demo_df['Average Score Reading White Grade 7 2018-2019']
white1922_7['Math'] = (demo22['Average Score Math White Grade 7 2021-2022'] - demo_df['Average Score Math White Grade 7 2018-2019'])/demo_df['Average Score Math White Grade 7 2018-2019']
white1922_7['Reading'] = (demo22['Average Score Reading White Grade 7 2021-2022'] - demo_df['Average Score Reading White Grade 7 2018-2019'])/demo_df['Average Score Reading White Grade 7 2018-2019']
white2122_7['Math'] = (demo22['Average Score Math White Grade 7 2021-2022'] - demo_df['Average Score Math White Grade 7 2020-2021'])/demo_df['Average Score Math White Grade 7 2020-2021']
white2122_7['Reading'] = (demo22['Average Score Reading White Grade 7 2021-2022'] - demo_df['Average Score Reading White Grade 7 2020-2021'])/demo_df['Average Score Reading White Grade 7 2020-2021']

hispanic1921_7['Math'] = (demo_df['Average Score Math Hispanic Grade 7 2020-2021'] - demo_df['Average Score Math Hispanic Grade 7 2018-2019'])/demo_df['Average Score Math Hispanic Grade 7 2018-2019']
hispanic1921_7['Reading'] = (demo_df['Average Score Reading Hispanic Grade 7 2020-2021'] - demo_df['Average Score Reading Hispanic Grade 7 2018-2019'])/demo_df['Average Score Reading Hispanic Grade 7 2018-2019']
hispanic1922_7['Math'] = (demo22['Average Score Math Hispanic Grade 7 2021-2022'] - demo_df['Average Score Math Hispanic Grade 7 2018-2019'])/demo_df['Average Score Math Hispanic Grade 7 2018-2019']
hispanic1922_7['Reading'] = (demo22['Average Score Reading Hispanic Grade 7 2021-2022'] - demo_df['Average Score Reading Hispanic Grade 7 2018-2019'])/demo_df['Average Score Reading Hispanic Grade 7 2018-2019']
hispanic2122_7['Math'] = (demo22['Average Score Math Hispanic Grade 7 2021-2022'] - demo_df['Average Score Math Hispanic Grade 7 2020-2021'])/demo_df['Average Score Math Hispanic Grade 7 2020-2021']
hispanic2122_7['Reading'] = (demo22['Average Score Reading Hispanic Grade 7 2021-2022'] - demo_df['Average Score Reading Hispanic Grade 7 2020-2021'])/demo_df['Average Score Reading Hispanic Grade 7 2020-2021']

black1921_7['Math'] = (demo_df['Average Score Math Black Grade 7 2020-2021'] - demo_df['Average Score Math Black Grade 7 2018-2019'])/demo_df['Average Score Math Black Grade 7 2018-2019']
black1921_7['Reading'] = (demo_df['Average Score Reading Black Grade 7 2020-2021'] - demo_df['Average Score Reading Black Grade 7 2018-2019'])/demo_df['Average Score Reading Black Grade 7 2018-2019']
black1922_7['Math'] = (demo22['Average Score Math Black Grade 7 2021-2022'] - demo_df['Average Score Math Black Grade 7 2018-2019'])/demo_df['Average Score Math Black Grade 7 2018-2019']
black1922_7['Reading'] = (demo22['Average Score Reading Black Grade 7 2021-2022'] - demo_df['Average Score Reading Black Grade 7 2018-2019'])/demo_df['Average Score Reading Black Grade 7 2018-2019']
black2122_7['Math'] = (demo22['Average Score Math Black Grade 7 2021-2022'] - demo_df['Average Score Math Black Grade 7 2020-2021'])/demo_df['Average Score Math Black Grade 7 2020-2021']
black2122_7['Reading'] = (demo22['Average Score Reading Black Grade 7 2021-2022'] - demo_df['Average Score Reading Black Grade 7 2020-2021'])/demo_df['Average Score Reading Black Grade 7 2020-2021']

freelunch1921_7['Math'] = (demo_df['Average Score Math Free Lunch Grade 7 2020-2021'] - demo_df['Average Score Math Free Lunch Grade 7 2018-2019'])/demo_df['Average Score Math Free Lunch Grade 7 2018-2019']
freelunch1921_7['Reading'] = (demo_df['Average Score Reading Free Lunch Grade 7 2020-2021'] - demo_df['Average Score Reading Free Lunch Grade 7 2018-2019'])/demo_df['Average Score Reading Free Lunch Grade 7 2018-2019']
freelunch1922_7['Math'] = (demo22['Average Score Math Free Lunch Grade 7 2021-2022'] - demo_df['Average Score Math Free Lunch Grade 7 2018-2019'])/demo_df['Average Score Math Free Lunch Grade 7 2018-2019']
freelunch1922_7['Reading'] = (demo22['Average Score Reading Free Lunch Grade 7 2021-2022'] - demo_df['Average Score Reading Free Lunch Grade 7 2018-2019'])/demo_df['Average Score Reading Free Lunch Grade 7 2018-2019']
freelunch2122_7['Math'] = (demo22['Average Score Math Free Lunch Grade 7 2021-2022'] - demo_df['Average Score Math Free Lunch Grade 7 2020-2021'])/demo_df['Average Score Math Free Lunch Grade 7 2020-2021']
freelunch2122_7['Reading'] = (demo22['Average Score Reading Free Lunch Grade 7 2021-2022'] - demo_df['Average Score Reading Free Lunch Grade 7 2020-2021'])/demo_df['Average Score Reading Free Lunch Grade 7 2020-2021']

poverty1921_7['Math'] = (demo_df['Average Score Math Poverty Grade 7 2020-2021'] - demo_df['Average Score Math Poverty Grade 7 2018-2019'])/demo_df['Average Score Math Poverty Grade 7 2018-2019']
poverty1921_7['Reading'] = (demo_df['Average Score Reading Poverty Grade 7 2020-2021'] - demo_df['Average Score Reading Poverty Grade 7 2018-2019'])/demo_df['Average Score Reading Poverty Grade 7 2018-2019']
poverty1922_7['Math'] = (demo22['Average Score Math Poverty Grade 7 2021-2022'] - demo_df['Average Score Math Poverty Grade 7 2018-2019'])/demo_df['Average Score Math Poverty Grade 7 2018-2019']
poverty1922_7['Reading'] = (demo22['Average Score Reading Poverty Grade 7 2021-2022'] - demo_df['Average Score Reading Poverty Grade 7 2018-2019'])/demo_df['Average Score Reading Poverty Grade 7 2018-2019']
poverty2122_7['Math'] = (demo22['Average Score Math Poverty Grade 7 2021-2022'] - demo_df['Average Score Math Poverty Grade 7 2020-2021'])/demo_df['Average Score Math Poverty Grade 7 2020-2021']
poverty2122_7['Reading'] = (demo22['Average Score Reading Poverty Grade 7 2021-2022'] - demo_df['Average Score Reading Poverty Grade 7 2020-2021'])/demo_df['Average Score Reading Poverty Grade 7 2020-2021']

specialed1921_7['Math'] = (demo_df['Average Score Math Special Ed Grade 7 2020-2021'] - demo_df['Average Score Math Special Ed Grade 7 2018-2019'])/demo_df['Average Score Math Special Ed Grade 7 2018-2019']
specialed1921_7['Reading'] = (demo_df['Average Score Reading Special Ed Grade 7 2020-2021'] - demo_df['Average Score Reading Special Ed Grade 7 2018-2019'])/demo_df['Average Score Reading Special Ed Grade 7 2018-2019']
specialed1922_7['Math'] = (demo22['Average Score Math Special Ed Grade 7 2021-2022'] - demo_df['Average Score Math Special Ed Grade 7 2018-2019'])/demo_df['Average Score Math Special Ed Grade 7 2018-2019']
specialed1922_7['Reading'] = (demo22['Average Score Reading Special Ed Grade 7 2021-2022'] - demo_df['Average Score Reading Special Ed Grade 7 2018-2019'])/demo_df['Average Score Reading Special Ed Grade 7 2018-2019']
specialed2122_7['Math'] = (demo22['Average Score Math Special Ed Grade 7 2021-2022'] - demo_df['Average Score Math Special Ed Grade 7 2020-2021'])/demo_df['Average Score Math Special Ed Grade 7 2020-2021']
specialed2122_7['Reading'] = (demo22['Average Score Reading Special Ed Grade 7 2021-2022'] - demo_df['Average Score Reading Special Ed Grade 7 2020-2021'])/demo_df['Average Score Reading Special Ed Grade 7 2020-2021']

t11921_7['Math'] = (demo_df['Average Score Math T1 Grade 7 2020-2021'] - demo_df['Average Score Math T1 Grade 7 2018-2019'])/demo_df['Average Score Math T1 Grade 7 2018-2019']
t11921_7['Reading'] = (demo_df['Average Score Reading T1 Grade 7 2020-2021'] - demo_df['Average Score Reading T1 Grade 7 2018-2019'])/demo_df['Average Score Reading T1 Grade 7 2018-2019']
t11922_7['Math'] = (demo22['Average Score Math T1 Grade 7 2021-2022'] - demo_df['Average Score Math T1 Grade 7 2018-2019'])/demo_df['Average Score Math T1 Grade 7 2018-2019']
t11922_7['Reading'] = (demo22['Average Score Reading T1 Grade 7 2021-2022'] - demo_df['Average Score Reading T1 Grade 7 2018-2019'])/demo_df['Average Score Reading T1 Grade 7 2018-2019']
t12122_7['Math'] = (demo22['Average Score Math T1 Grade 7 2021-2022'] - demo_df['Average Score Math T1 Grade 7 2020-2021'])/demo_df['Average Score Math T1 Grade 7 2020-2021']
t12122_7['Reading'] = (demo22['Average Score Reading T1 Grade 7 2021-2022'] - demo_df['Average Score Reading T1 Grade 7 2020-2021'])/demo_df['Average Score Reading T1 Grade 7 2020-2021']

with pd.option_context('mode.use_inf_as_na', True):

  #  t11921.fillna(0,inplace=True)
 #   t11922.fillna(0,inplace=True)
  #  t12122.fillna(0,inplace=True)

    asian1921_7.fillna(0,inplace=True)
    all1921_7.fillna(0,inplace=True)
    white1921_7.fillna(0,inplace=True)
    black1921_7.fillna(0,inplace=True)
    freelunch1921_7.fillna(0,inplace=True)
    poverty1921_7.fillna(0,inplace=True)
    hispanic1921_7.fillna(0,inplace=True)
    specialed1921_7.fillna(0,inplace=True)

    asian1922_7.fillna(0,inplace=True)
    all1922_7.fillna(0,inplace=True)
    white1922_7.fillna(0,inplace=True)
    black1922_7.fillna(0,inplace=True)
    freelunch1922_7.fillna(0,inplace=True)
    poverty1922_7.fillna(0,inplace=True)
    hispanic1922_7.fillna(0,inplace=True)
    specialed1922_7.fillna(0,inplace=True)

    asian2122_7.fillna(0,inplace=True)
    all2122_7.fillna(0,inplace=True)
    white2122_7.fillna(0,inplace=True)
    black2122_7.fillna(0,inplace=True)
    freelunch2122_7.fillna(0,inplace=True)
    poverty2122_7.fillna(0,inplace=True)
    hispanic2122_7.fillna(0,inplace=True)
    specialed2122_7.fillna(0,inplace=True)

asian1921_7 = asian1921_7 *100
all1921_7 = all1921_7 *100
white1921_7 = white1921_7*100
black1921_7 = black1921_7*100
freelunch1921_7 = freelunch1921_7*100
poverty1921_7 = poverty1921_7*100
hispanic1921_7 = hispanic1921_7*100
specialed1921_7 = specialed1921_7*100

asian1922_7 = asian1922_7*100
all1922_7 = all1922_7*100
white1922_7 = white1922_7*100
black1922_7 = black1922_7*100
freelunch1922_7 = freelunch1922_7*100
poverty1922_7 = poverty1922_7*100
hispanic1922_7 = hispanic1922_7*100
specialed1922_7 = specialed1922_7*100

asian2122_7 = asian2122_7*100
all2122_7 = all2122_7*100
white2122_7 = white2122_7*100
black2122_7 = black2122_7*100
freelunch2122_7 = freelunch2122_7*100
poverty2122_7 = poverty2122_7*100
hispanic2122_7 = hispanic2122_7*100
specialed2122_7 = specialed2122_7*100

asian1921_7 = asian1921_7.astype(int)
all1921_7 = all1921_7.astype(int)
white1921_7 = white1921_7.astype(int)
black1921_7 = black1921_7.astype(int)
freelunch1921_7 = freelunch1921_7.astype(int)
poverty1921_7 = poverty1921_7.astype(int)
hispanic1921_7 = hispanic1921_7.astype(int)
specialed1921_7 = specialed1921_7.astype(int)

asian1922_7 = asian1922_7.astype(int)
all1922_7 = all1922_7.astype(int)
white1922_7 = white1922_7.astype(int)
black1922_7 = black1922_7.astype(int)
freelunch1922_7 = freelunch1922_7.astype(int)
poverty1922_7 = poverty1922_7.astype(int)
hispanic1922_7 = hispanic1922_7.astype(int)
specialed1922_7 = specialed1922_7.astype(int)

asian2122_7 = asian2122_7.astype(int)
all2122_7 = all2122_7.astype(int)
white2122_7 = white2122_7.astype(int)
black2122_7 = black2122_7.astype(int)
freelunch2122_7 = freelunch2122_7.astype(int)
poverty2122_7 = poverty2122_7.astype(int)
hispanic2122_7 = hispanic2122_7.astype(int)
specialed2122_7 = specialed2122_7.astype(int)

# %%
asian1921_8 = pd.DataFrame()
asian1922_8 = pd.DataFrame()
asian2122_8 = pd.DataFrame()

black1921_8 = pd.DataFrame()
black1922_8 = pd.DataFrame()
black2122_8 = pd.DataFrame()

all1921_8 = pd.DataFrame()
all1922_8 = pd.DataFrame()
all2122_8 = pd.DataFrame()

white1921_8 = pd.DataFrame()
white1922_8 = pd.DataFrame()
white2122_8 = pd.DataFrame()

freelunch1921_8 = pd.DataFrame()
freelunch1922_8 = pd.DataFrame()
freelunch2122_8 = pd.DataFrame()



hispanic1921_8 = pd.DataFrame()
hispanic1922_8 = pd.DataFrame()
hispanic2122_8 = pd.DataFrame()

poverty1921_8 = pd.DataFrame()
poverty1922_8 = pd.DataFrame()
poverty2122_8 = pd.DataFrame()

t11921_8 = pd.DataFrame()
t11922_8 = pd.DataFrame()
t12122_8 = pd.DataFrame()

specialed1921_8 = pd.DataFrame()
specialed1922_8 = pd.DataFrame()
specialed2122_8 = pd.DataFrame()

all1921_8['Math'] = (demo_df['Average Score Math All Grade 8 2020-2021'] - demo_df['Average Score Math All Grade 8 2018-2019'])/demo_df['Average Score Math All Grade 8 2018-2019']
all1921_8['Reading'] = (demo_df['Average Score Reading All Grade 8 2020-2021'] - demo_df['Average Score Reading All Grade 8 2018-2019'])/demo_df['Average Score Reading All Grade 8 2018-2019']
all1922_8['Math'] = (demo22['Average Score Math All Grade 8 2021-2022'] - demo_df['Average Score Math All Grade 8 2018-2019'])/demo_df['Average Score Math All Grade 8 2018-2019']
all1922_8['Reading'] = (demo22['Average Score Reading All Grade 8 2021-2022'] - demo_df['Average Score Reading All Grade 8 2018-2019'])/demo_df['Average Score Reading All Grade 8 2018-2019']
all2122_8['Math'] = (demo22['Average Score Math All Grade 8 2021-2022'] - demo_df['Average Score Math All Grade 8 2020-2021'])/demo_df['Average Score Math All Grade 8 2020-2021']
all2122_8['Reading'] = (demo22['Average Score Reading All Grade 8 2021-2022'] - demo_df['Average Score Reading All Grade 8 2020-2021'])/demo_df['Average Score Reading All Grade 8 2020-2021']

white1921_8['Math'] = (demo_df['Average Score Math White Grade 8 2020-2021'] - demo_df['Average Score Math White Grade 8 2018-2019'])/demo_df['Average Score Math White Grade 8 2018-2019']
white1921_8['Reading'] = (demo_df['Average Score Reading White Grade 8 2020-2021'] - demo_df['Average Score Reading White Grade 8 2018-2019'])/demo_df['Average Score Reading White Grade 8 2018-2019']
white1922_8['Math'] = (demo22['Average Score Math White Grade 8 2021-2022'] - demo_df['Average Score Math White Grade 8 2018-2019'])/demo_df['Average Score Math White Grade 8 2018-2019']
white1922_8['Reading'] = (demo22['Average Score Reading White Grade 8 2021-2022'] - demo_df['Average Score Reading White Grade 8 2018-2019'])/demo_df['Average Score Reading White Grade 8 2018-2019']
white2122_8['Math'] = (demo22['Average Score Math White Grade 8 2021-2022'] - demo_df['Average Score Math White Grade 8 2020-2021'])/demo_df['Average Score Math White Grade 8 2020-2021']
white2122_8['Reading'] = (demo22['Average Score Reading White Grade 8 2021-2022'] - demo_df['Average Score Reading White Grade 8 2020-2021'])/demo_df['Average Score Reading White Grade 8 2020-2021']

hispanic1921_8['Math'] = (demo_df['Average Score Math Hispanic Grade 8 2020-2021'] - demo_df['Average Score Math Hispanic Grade 8 2018-2019'])/demo_df['Average Score Math Hispanic Grade 8 2018-2019']
hispanic1921_8['Reading'] = (demo_df['Average Score Reading Hispanic Grade 8 2020-2021'] - demo_df['Average Score Reading Hispanic Grade 8 2018-2019'])/demo_df['Average Score Reading Hispanic Grade 8 2018-2019']
hispanic1922_8['Math'] = (demo22['Average Score Math Hispanic Grade 8 2021-2022'] - demo_df['Average Score Math Hispanic Grade 8 2018-2019'])/demo_df['Average Score Math Hispanic Grade 8 2018-2019']
hispanic1922_8['Reading'] = (demo22['Average Score Reading Hispanic Grade 8 2021-2022'] - demo_df['Average Score Reading Hispanic Grade 8 2018-2019'])/demo_df['Average Score Reading Hispanic Grade 8 2018-2019']
hispanic2122_8['Math'] = (demo22['Average Score Math Hispanic Grade 8 2021-2022'] - demo_df['Average Score Math Hispanic Grade 8 2020-2021'])/demo_df['Average Score Math Hispanic Grade 8 2020-2021']
hispanic2122_8['Reading'] = (demo22['Average Score Reading Hispanic Grade 8 2021-2022'] - demo_df['Average Score Reading Hispanic Grade 8 2020-2021'])/demo_df['Average Score Reading Hispanic Grade 8 2020-2021']

black1921_8['Math'] = (demo_df['Average Score Math Black Grade 8 2020-2021'] - demo_df['Average Score Math Black Grade 8 2018-2019'])/demo_df['Average Score Math Black Grade 8 2018-2019']
black1921_8['Reading'] = (demo_df['Average Score Reading Black Grade 8 2020-2021'] - demo_df['Average Score Reading Black Grade 8 2018-2019'])/demo_df['Average Score Reading Black Grade 8 2018-2019']
black1922_8['Math'] = (demo22['Average Score Math Black Grade 8 2021-2022'] - demo_df['Average Score Math Black Grade 8 2018-2019'])/demo_df['Average Score Math Black Grade 8 2018-2019']
black1922_8['Reading'] = (demo22['Average Score Reading Black Grade 8 2021-2022'] - demo_df['Average Score Reading Black Grade 8 2018-2019'])/demo_df['Average Score Reading Black Grade 8 2018-2019']
black2122_8['Math'] = (demo22['Average Score Math Black Grade 8 2021-2022'] - demo_df['Average Score Math Black Grade 8 2020-2021'])/demo_df['Average Score Math Black Grade 8 2020-2021']
black2122_8['Reading'] = (demo22['Average Score Reading Black Grade 8 2021-2022'] - demo_df['Average Score Reading Black Grade 8 2020-2021'])/demo_df['Average Score Reading Black Grade 8 2020-2021']

freelunch1921_8['Math'] = (demo_df['Average Score Math Free Lunch Grade 8 2020-2021'] - demo_df['Average Score Math Free Lunch Grade 8 2018-2019'])/demo_df['Average Score Math Free Lunch Grade 8 2018-2019']
freelunch1921_8['Reading'] = (demo_df['Average Score Reading Free Lunch Grade 8 2020-2021'] - demo_df['Average Score Reading Free Lunch Grade 8 2018-2019'])/demo_df['Average Score Reading Free Lunch Grade 8 2018-2019']
freelunch1922_8['Math'] = (demo22['Average Score Math Free Lunch Grade 8 2021-2022'] - demo_df['Average Score Math Free Lunch Grade 8 2018-2019'])/demo_df['Average Score Math Free Lunch Grade 8 2018-2019']
freelunch1922_8['Reading'] = (demo22['Average Score Reading Free Lunch Grade 8 2021-2022'] - demo_df['Average Score Reading Free Lunch Grade 8 2018-2019'])/demo_df['Average Score Reading Free Lunch Grade 8 2018-2019']
freelunch2122_8['Math'] = (demo22['Average Score Math Free Lunch Grade 8 2021-2022'] - demo_df['Average Score Math Free Lunch Grade 8 2020-2021'])/demo_df['Average Score Math Free Lunch Grade 8 2020-2021']
freelunch2122_8['Reading'] = (demo22['Average Score Reading Free Lunch Grade 8 2021-2022'] - demo_df['Average Score Reading Free Lunch Grade 8 2020-2021'])/demo_df['Average Score Reading Free Lunch Grade 8 2020-2021']

poverty1921_8['Math'] = (demo_df['Average Score Math Poverty Grade 8 2020-2021'] - demo_df['Average Score Math Poverty Grade 8 2018-2019'])/demo_df['Average Score Math Poverty Grade 8 2018-2019']
poverty1921_8['Reading'] = (demo_df['Average Score Reading Poverty Grade 8 2020-2021'] - demo_df['Average Score Reading Poverty Grade 8 2018-2019'])/demo_df['Average Score Reading Poverty Grade 8 2018-2019']
poverty1922_8['Math'] = (demo22['Average Score Math Poverty Grade 8 2021-2022'] - demo_df['Average Score Math Poverty Grade 8 2018-2019'])/demo_df['Average Score Math Poverty Grade 8 2018-2019']
poverty1922_8['Reading'] = (demo22['Average Score Reading Poverty Grade 8 2021-2022'] - demo_df['Average Score Reading Poverty Grade 8 2018-2019'])/demo_df['Average Score Reading Poverty Grade 8 2018-2019']
poverty2122_8['Math'] = (demo22['Average Score Math Poverty Grade 8 2021-2022'] - demo_df['Average Score Math Poverty Grade 8 2020-2021'])/demo_df['Average Score Math Poverty Grade 8 2020-2021']
poverty2122_8['Reading'] = (demo22['Average Score Reading Poverty Grade 8 2021-2022'] - demo_df['Average Score Reading Poverty Grade 8 2020-2021'])/demo_df['Average Score Reading Poverty Grade 8 2020-2021']

specialed1921_8['Math'] = (demo_df['Average Score Math Special Ed Grade 8 2020-2021'] - demo_df['Average Score Math Special Ed Grade 8 2018-2019'])/demo_df['Average Score Math Special Ed Grade 8 2018-2019']
specialed1921_8['Reading'] = (demo_df['Average Score Reading Special Ed Grade 8 2020-2021'] - demo_df['Average Score Reading Special Ed Grade 8 2018-2019'])/demo_df['Average Score Reading Special Ed Grade 8 2018-2019']
specialed1922_8['Math'] = (demo22['Average Score Math Special Ed Grade 8 2021-2022'] - demo_df['Average Score Math Special Ed Grade 8 2018-2019'])/demo_df['Average Score Math Special Ed Grade 8 2018-2019']
specialed1922_8['Reading'] = (demo22['Average Score Reading Special Ed Grade 8 2021-2022'] - demo_df['Average Score Reading Special Ed Grade 8 2018-2019'])/demo_df['Average Score Reading Special Ed Grade 8 2018-2019']
specialed2122_8['Math'] = (demo22['Average Score Math Special Ed Grade 8 2021-2022'] - demo_df['Average Score Math Special Ed Grade 8 2020-2021'])/demo_df['Average Score Math Special Ed Grade 8 2020-2021']
specialed2122_8['Reading'] = (demo22['Average Score Reading Special Ed Grade 8 2021-2022'] - demo_df['Average Score Reading Special Ed Grade 8 2020-2021'])/demo_df['Average Score Reading Special Ed Grade 8 2020-2021']

t11921_8['Math'] = (demo_df['Average Score Math T1 Grade 8 2020-2021'] - demo_df['Average Score Math T1 Grade 8 2018-2019'])/demo_df['Average Score Math T1 Grade 8 2018-2019']
t11921_8['Reading'] = (demo_df['Average Score Reading T1 Grade 8 2020-2021'] - demo_df['Average Score Reading T1 Grade 8 2018-2019'])/demo_df['Average Score Reading T1 Grade 8 2018-2019']
t11922_8['Math'] = (demo22['Average Score Math T1 Grade 8 2021-2022'] - demo_df['Average Score Math T1 Grade 8 2018-2019'])/demo_df['Average Score Math T1 Grade 8 2018-2019']
t11922_8['Reading'] = (demo22['Average Score Reading T1 Grade 8 2021-2022'] - demo_df['Average Score Reading T1 Grade 8 2018-2019'])/demo_df['Average Score Reading T1 Grade 8 2018-2019']
t12122_8['Math'] = (demo22['Average Score Math T1 Grade 8 2021-2022'] - demo_df['Average Score Math T1 Grade 8 2020-2021'])/demo_df['Average Score Math T1 Grade 8 2020-2021']
t12122_8['Reading'] = (demo22['Average Score Reading T1 Grade 8 2021-2022'] - demo_df['Average Score Reading T1 Grade 8 2020-2021'])/demo_df['Average Score Reading T1 Grade 8 2020-2021']

with pd.option_context('mode.use_inf_as_na', True):

  #  t11921.fillna(0,inplace=True)
  #  t11922.fillna(0,inplace=True)
  #  t12122.fillna(0,inplace=True)

    asian1921_8.fillna(0,inplace=True)
    all1921_8.fillna(0,inplace=True)
    white1921_8.fillna(0,inplace=True)
    black1921_8.fillna(0,inplace=True)
    freelunch1921_8.fillna(0,inplace=True)
    poverty1921_8.fillna(0,inplace=True)
    hispanic1921_8.fillna(0,inplace=True)
    specialed1921_8.fillna(0,inplace=True)

    asian1922_8.fillna(0,inplace=True)
    all1922_8.fillna(0,inplace=True)
    white1922_8.fillna(0,inplace=True)
    black1922_8.fillna(0,inplace=True)
    freelunch1922_8.fillna(0,inplace=True)
    poverty1922_8.fillna(0,inplace=True)
    hispanic1922_8.fillna(0,inplace=True)
    specialed1922_8.fillna(0,inplace=True)

    asian2122_8.fillna(0,inplace=True)
    all2122_8.fillna(0,inplace=True)
    white2122_8.fillna(0,inplace=True)
    black2122_8.fillna(0,inplace=True)
    freelunch2122_8.fillna(0,inplace=True)
    poverty2122_8.fillna(0,inplace=True)
    hispanic2122_8.fillna(0,inplace=True)
    specialed2122_8.fillna(0,inplace=True)

asian1921_8 = asian1921_8 *100
all1921_8 = all1921_8 *100
white1921_8 = white1921_8*100
black1921_8 = black1921_8*100
freelunch1921_8 = freelunch1921_8*100
poverty1921_8 = poverty1921_8*100
hispanic1921_8 = hispanic1921_8*100
specialed1921_8 = specialed1921_8*100

asian1922_8 = asian1922_8*100
all1922_8 = all1922_8*100
white1922_8 = white1922_8*100
black1922_8 = black1922_8*100
freelunch1922_8 = freelunch1922_8*100
poverty1922_8 = poverty1922_8*100
hispanic1922_8 = hispanic1922_8*100
specialed1922_8 = specialed1922_8*100

asian2122_8 = asian2122_8*100
all2122_8 = all2122_8*100
white2122_8 = white2122_8*100
black2122_8 = black2122_8*100
freelunch2122_8 = freelunch2122_8*100
poverty2122_8 = poverty2122_8*100
hispanic2122_8 = hispanic2122_8*100
specialed2122_8 = specialed2122_8*100

asian1921_8 = asian1921_8.astype(int)
all1921_8 = all1921_8.astype(int)
white1921_8 = white1921_8.astype(int)
black1921_8 = black1921_8.astype(int)
freelunch1921_8 = freelunch1921_8.astype(int)
poverty1921_8 = poverty1921_8.astype(int)
hispanic1921_8 = hispanic1921_8.astype(int)
specialed1921_8 = specialed1921_8.astype(int)

asian1922_8 = asian1922_8.astype(int)
all1922_8 = all1922_8.astype(int)
white1922_8 = white1922_8.astype(int)
black1922_8 = black1922_8.astype(int)
freelunch1922_8 = freelunch1922_8.astype(int)
poverty1922_8 = poverty1922_8.astype(int)
hispanic1922_8 = hispanic1922_8.astype(int)
specialed1922_8 = specialed1922_8.astype(int)

asian2122_8 = asian2122_8.astype(int)
all2122_8 = all2122_8.astype(int)
white2122_8 = white2122_8.astype(int)
black2122_8 = black2122_8.astype(int)
freelunch2122_8 = freelunch2122_8.astype(int)
poverty2122_8 = poverty2122_8.astype(int)
hispanic2122_8 = hispanic2122_8.astype(int)
specialed2122_8 = specialed2122_8.astype(int)

# %% [markdown]
# asian1921['Math'] = (demo_df['Average Score Math Asian Grade 3 2020-2021'] - demo_df['Average Score Math Asian Grade 3 2018-2019'])/demo_df['Average Score Math Asian Grade 3 2018-2019']
# asian1921['Reading'] = (demo_df['Average Score Reading Asian Grade 3 2020-2021'] - demo_df['Average Score Reading Asian Grade 3 2018-2019'])/demo_df['Average Score Reading Asian Grade 3 2018-2019']
# asian1922['Math'] = (demo22['Average Score Math Asian Grade 3 2021-2022'] - demo_df['Average Score Math Asian Grade 3 2018-2019'])/demo_df['Average Score Math Asian Grade 3 2018-2019']
# asian1922['Reading'] = (demo22['Average Score Reading Asian Grade 3 2021-2022'] - demo_df['Average Score Reading Asian Grade 3 2018-2019'])/demo_df['Average Score Reading Asian Grade 3 2018-2019']
# asian2122['Math'] = (demo22['Average Score Math Asian Grade 3 2021-2022'] - demo_df['Average Score Math Asian Grade 3 2020-2021'])/demo_df['Average Score Math Asian Grade 3 2020-2021']
# asian2122['Reading'] = (demo22['Average Score Reading Asian Grade 3 2021-2022'] - demo_df['Average Score Reading Asian Grade 3 2020-2021'])/demo_df['Average Score Reading Asian Grade 3 2020-2021']

# %%
asian1921_3.isna().sum()
# Out:
# Series([], dtype: float64)

# %%
black1921_3
# Out:
#      Math  Reading
# 0      -5       -2
# 1       0        0
# 2      -5       -1
# 3       0        0
# 4       0        0
# ..    ...      ...
# 248     0        0
# 249     0        0
# 250     0        0
# 251     0        0
# 252     0        0
#
# [253 rows x 2 columns]

# %%
all1921_3
# Out:
#      Math  Reading
# 0      -1        2
# 1      -5        0
# 2      -2        1
# 3      -3        1
# 4      -5        0
# ..    ...      ...
# 248    -4        0
# 249    -4        1
# 250     0        3
# 251   -10       -5
# 252    -7       -3
#
# [253 rows x 2 columns]

# %%
#Creates a county level map of Texas based on the Texas Education Agency Data
input_list = ['All','Black','Free Lunch','Hispanic','Poverty','Special-Ed','White']
#input_list = input_list.sort()
subject_list = ['Math','Reading']
grade_list = ['3rd','4th','5th','6th','7th','8th']
# Labor Force Taken out for now 2019-2021
year_list = ['2019-2021','2021-2022','2019-2022']
class MapDashboard(param.Parameterized):
    _  = param.Selector(default=input_list[0],objects=input_list)
    __ = param.Selector(default=year_list[0],objects=year_list)
    ___ = param.Selector(default=subject_list[0],objects=subject_list)
    ____ = param.Selector(default= grade_list[0],objects=grade_list)
    #@param.depends('_')
    def get_map(self):
        if self.____ == '3rd':
            if self.__ == '2019-2021':
#                if self._ == 'Asian':
#                    data = asian1921[[self.___]]
                if self._ == 'All':
                    data = all1921_3[[self.___]]
                elif self._ == 'Black':
                    data = black1921_3[[self.___]]
                elif self._ == 'White':
                    data = white1921_3[[self.___]]
                elif self._ == 'Free Lunch':
                    data = freelunch1921_3[[self.___]]
                elif self._ == 'Hispanic':
                    data = hispanic1921_3[[self.___]]
                elif self._ == 'Poverty':
                    data = poverty1921_3[[self.___]]
                elif self._ == 'Special-Ed':
                    data = specialed1921_3[[self.___]]
     #           elif self._ == 'T1':
      #              data = t11921[[self.___]]
                
            elif self.__ == '2019-2022':
#                if self._ == 'Asian':
#                    data = asian1922[[self.___]]
                if self._ == 'All':
                    data = all1922_3[[self.___]]
                elif self._ == 'Black':
                    data = black1922_3[[self.___]]
                elif self._ == 'White':
                    data = white1922_3[[self.___]]
                elif self._ == 'Free Lunch':
                    data = freelunch1922_3[[self.___]]
                elif self._ == 'Hispanic':
                    data = hispanic1922_3[[self.___]]
                elif self._ == 'Poverty':
                    data = poverty1922_3[[self.___]]
                elif self._ == 'Special-Ed':
                    data = specialed1922_3[[self.___]]
#                elif self._ == 'T1':
#                    data = t11922[[self.___]]
            elif self.__ == '2021-2022':
#                if self._ == 'Asian':
#                    data = asian2122[[self.___]]
                if self._ == 'All':
                    data = all2122_3[[self.___]]
                elif self._ == 'Black':
                    data = black2122_3[[self.___]]
                elif self._ == 'White':
                    data = white2122_3[[self.___]]
                elif self._ == 'Free Lunch':
                    data = freelunch2122_3[[self.___]]
                elif self._ == 'Hispanic':
                    data = hispanic2122_3[[self.___]]
                elif self._ == 'Poverty':
                    data = poverty2122_3[[self.___]]
                elif self._ == 'Special-Ed':
                    data = specialed2122_3[[self.___]]
#                elif self._ == 'T1':
#                    data = t12122[[self.___]]
        elif self.____ == '4th':
            if self.__ == '2019-2021':
#                if self._ == 'Asian':
#                    data = asian1921[[self.___]]
                if self._ == 'All':
                    data = all1921_4[[self.___]]
                elif self._ == 'Black':
                    data = black1921_4[[self.___]]
                elif self._ == 'White':
                    data = white1921_4[[self.___]]
                elif self._ == 'Free Lunch':
                    data = freelunch1921_4[[self.___]]
                elif self._ == 'Hispanic':
                    data = hispanic1921_4[[self.___]]
                elif self._ == 'Poverty':
                    data = poverty1921_4[[self.___]]
                elif self._ == 'Special-Ed':
                    data = specialed1921_4[[self.___]]
     #           elif self._ == 'T1':
      #              data = t11921[[self.___]]
                
            elif self.__ == '2019-2022':
#                if self._ == 'Asian':
#                    data = asian1922[[self.___]]
                if self._ == 'All':
                    data = all1922_4[[self.___]]
                elif self._ == 'Black':
                    data = black1922_4[[self.___]]
                elif self._ == 'White':
                    data = white1922_4[[self.___]]
                elif self._ == 'Free Lunch':
                    data = freelunch1922_4[[self.___]]
                elif self._ == 'Hispanic':
                    data = hispanic1922_4[[self.___]]
                elif self._ == 'Poverty':
                    data = poverty1922_4[[self.___]]
                elif self._ == 'Special-Ed':
                    data = specialed1922_4[[self.___]]
#                elif self._ == 'T1':
#                    data = t11922[[self.___]]
            elif self.__ == '2021-2022':
#                if self._ == 'Asian':
#                    data = asian2122[[self.___]]
                if self._ == 'All':
                    data = all2122_4[[self.___]]
                elif self._ == 'Black':
                    data = black2122_4[[self.___]]
                elif self._ == 'White':
                    data = white2122_4[[self.___]]
                elif self._ == 'Free Lunch':
                    data = freelunch2122_4[[self.___]]
                elif self._ == 'Hispanic':
                    data = hispanic2122_4[[self.___]]
                elif self._ == 'Poverty':
                    data = poverty2122_4[[self.___]]
                elif self._ == 'Special-Ed':
                    data = specialed2122_4[[self.___]]
#                elif self._ == 'T1':
#                    data = t12122[[self.___]]
        elif self.____ == '5th':
            if self.__ == '2019-2021':
#                if self._ == 'Asian':
#                    data = asian1921[[self.___]]
                if self._ == 'All':
                    data = all1921_5[[self.___]]
                elif self._ == 'Black':
                    data = black1921_5[[self.___]]
                elif self._ == 'White':
                    data = white1921_5[[self.___]]
                elif self._ == 'Free Lunch':
                    data = freelunch1921_5[[self.___]]
                elif self._ == 'Hispanic':
                    data = hispanic1921_5[[self.___]]
                elif self._ == 'Poverty':
                    data = poverty1921_5[[self.___]]
                elif self._ == 'Special-Ed':
                    data = specialed1921_5[[self.___]]
     #           elif self._ == 'T1':
      #              data = t11921[[self.___]]
                
            elif self.__ == '2019-2022':
#                if self._ == 'Asian':
#                    data = asian1922[[self.___]]
                if self._ == 'All':
                    data = all1922_5[[self.___]]
                elif self._ == 'Black':
                    data = black1922_5[[self.___]]
                elif self._ == 'White':
                    data = white1922_5[[self.___]]
                elif self._ == 'Free Lunch':
                    data = freelunch1922_5[[self.___]]
                elif self._ == 'Hispanic':
                    data = hispanic1922_5[[self.___]]
                elif self._ == 'Poverty':
                    data = poverty1922_5[[self.___]]
                elif self._ == 'Special-Ed':
                    data = specialed1922_5[[self.___]]
#                elif self._ == 'T1':
#                    data = t11922[[self.___]]
            elif self.__ == '2021-2022':
#                if self._ == 'Asian':
#                    data = asian2122[[self.___]]
                if self._ == 'All':
                    data = all2122_5[[self.___]]
                elif self._ == 'Black':
                    data = black2122_5[[self.___]]
                elif self._ == 'White':
                    data = white2122_5[[self.___]]
                elif self._ == 'Free Lunch':
                    data = freelunch2122_5[[self.___]]
                elif self._ == 'Hispanic':
                    data = hispanic2122_5[[self.___]]
                elif self._ == 'Poverty':
                    data = poverty2122_5[[self.___]]
                elif self._ == 'Special-Ed':
                    data = specialed2122_5[[self.___]]
#                elif self._ == 'T1':
#                    data = t12122[[self.___]]
        elif self.____ == '6th':
            if self.__ == '2019-2021':
#                if self._ == 'Asian':
#                    data = asian1921[[self.___]]
                if self._ == 'All':
                    data = all1921_6[[self.___]]
                elif self._ == 'Black':
                    data = black1921_6[[self.___]]
                elif self._ == 'White':
                    data = white1921_6[[self.___]]
                elif self._ == 'Free Lunch':
                    data = freelunch1921_6[[self.___]]
                elif self._ == 'Hispanic':
                    data = hispanic1921_6[[self.___]]
                elif self._ == 'Poverty':
                    data = poverty1921_6[[self.___]]
                elif self._ == 'Special-Ed':
                    data = specialed1921_6[[self.___]]
     #           elif self._ == 'T1':
      #              data = t11921[[self.___]]
                
            elif self.__ == '2019-2022':
#                if self._ == 'Asian':
#                    data = asian1922[[self.___]]
                if self._ == 'All':
                    data = all1922_6[[self.___]]
                elif self._ == 'Black':
                    data = black1922_6[[self.___]]
                elif self._ == 'White':
                    data = white1922_6[[self.___]]
                elif self._ == 'Free Lunch':
                    data = freelunch1922_6[[self.___]]
                elif self._ == 'Hispanic':
                    data = hispanic1922_6[[self.___]]
                elif self._ == 'Poverty':
                    data = poverty1922_6[[self.___]]
                elif self._ == 'Special-Ed':
                    data = specialed1922_6[[self.___]]
#                elif self._ == 'T1':
#                    data = t11922[[self.___]]
            elif self.__ == '2021-2022':
#                if self._ == 'Asian':
#                    data = asian2122[[self.___]]
                if self._ == 'All':
                    data = all2122_6[[self.___]]
                elif self._ == 'Black':
                    data = black2122_6[[self.___]]
                elif self._ == 'White':
                    data = white2122_6[[self.___]]
                elif self._ == 'Free Lunch':
                    data = freelunch2122_6[[self.___]]
                elif self._ == 'Hispanic':
                    data = hispanic2122_6[[self.___]]
                elif self._ == 'Poverty':
                    data = poverty2122_6[[self.___]]
                elif self._ == 'Special-Ed':
                    data = specialed2122_6[[self.___]]
#                elif self._ == 'T1':
#                    data = t12122[[self.___]]
        elif self.____ == '7th':
            if self.__ == '2019-2021':
#                if self._ == 'Asian':
#                    data = asian1921[[self.___]]
                if self._ == 'All':
                    data = all1921_7[[self.___]]
                elif self._ == 'Black':
                    data = black1921_7[[self.___]]
                elif self._ == 'White':
                    data = white1921_7[[self.___]]
                elif self._ == 'Free Lunch':
                    data = freelunch1921_7[[self.___]]
                elif self._ == 'Hispanic':
                    data = hispanic1921_7[[self.___]]
                elif self._ == 'Poverty':
                    data = poverty1921_7[[self.___]]
                elif self._ == 'Special-Ed':
                    data = specialed1921_7[[self.___]]
     #           elif self._ == 'T1':
      #              data = t11921[[self.___]]
                
            elif self.__ == '2019-2022':
#                if self._ == 'Asian':
#                    data = asian1922[[self.___]]
                if self._ == 'All':
                    data = all1922_7[[self.___]]
                elif self._ == 'Black':
                    data = black1922_7[[self.___]]
                elif self._ == 'White':
                    data = white1922_7[[self.___]]
                elif self._ == 'Free Lunch':
                    data = freelunch1922_7[[self.___]]
                elif self._ == 'Hispanic':
                    data = hispanic1922_7[[self.___]]
                elif self._ == 'Poverty':
                    data = poverty1922_7[[self.___]]
                elif self._ == 'Special-Ed':
                    data = specialed1922_7[[self.___]]
#                elif self._ == 'T1':
#                    data = t11922[[self.___]]
            elif self.__ == '2021-2022':
#                if self._ == 'Asian':
#                    data = asian2122[[self.___]]
                if self._ == 'All':
                    data = all2122_7[[self.___]]
                elif self._ == 'Black':
                    data = black2122_7[[self.___]]
                elif self._ == 'White':
                    data = white2122_7[[self.___]]
                elif self._ == 'Free Lunch':
                    data = freelunch2122_7[[self.___]]
                elif self._ == 'Hispanic':
                    data = hispanic2122_7[[self.___]]
                elif self._ == 'Poverty':
                    data = poverty2122_7[[self.___]]
                elif self._ == 'Special-Ed':
                    data = specialed2122_7[[self.___]]
#                elif self._ == 'T1':
#                    data = t12122[[self.___]]
        elif self.____ == '8th':
            if self.__ == '2019-2021':
#                if self._ == 'Asian':
#                    data = asian1921[[self.___]]
                if self._ == 'All':
                    data = all1921_8[[self.___]]
                elif self._ == 'Black':
                    data = black1921_8[[self.___]]
                elif self._ == 'White':
                    data = white1921_8[[self.___]]
                elif self._ == 'Free Lunch':
                    data = freelunch1921_8[[self.___]]
                elif self._ == 'Hispanic':
                    data = hispanic1921_8[[self.___]]
                elif self._ == 'Poverty':
                    data = poverty1921_8[[self.___]]
                elif self._ == 'Special-Ed':
                    data = specialed1921_8[[self.___]]
     #           elif self._ == 'T1':
      #              data = t11921[[self.___]]
                
            elif self.__ == '2019-2022':
#                if self._ == 'Asian':
#                    data = asian1922[[self.___]]
                if self._ == 'All':
                    data = all1922_8[[self.___]]
                elif self._ == 'Black':
                    data = black1922_8[[self.___]]
                elif self._ == 'White':
                    data = white1922_8[[self.___]]
                elif self._ == 'Free Lunch':
                    data = freelunch1922_8[[self.___]]
                elif self._ == 'Hispanic':
                    data = hispanic1922_8[[self.___]]
                elif self._ == 'Poverty':
                    data = poverty1922_8[[self.___]]
                elif self._ == 'Special-Ed':
                    data = specialed1922_8[[self.___]]
#                elif self._ == 'T1':
#                    data = t11922[[self.___]]
            elif self.__ == '2021-2022':
#                if self._ == 'Asian':
#                    data = asian2122[[self.___]]
                if self._ == 'All':
                    data = all2122_8[[self.___]]
                elif self._ == 'Black':
                    data = black2122_8[[self.___]]
                elif self._ == 'White':
                    data = white2122_8[[self.___]]
                elif self._ == 'Free Lunch':
                    data = freelunch2122_8[[self.___]]
                elif self._ == 'Hispanic':
                    data = hispanic2122_8[[self.___]]
                elif self._ == 'Poverty':
                    data = poverty2122_8[[self.___]]
                elif self._ == 'Special-Ed':
                    data = specialed2122_8[[self.___]]
#                elif self._ == 'T1':
#                    data = t12122[[self.___]]
        data['County #'] = demo_df['County #']
        data['County Name'] = demo_df['County Name']
                        
        fig = px.choropleth_mapbox(data, geojson=counties, locations='County #', color= self.___,
        color_continuous_scale='balance_r',
        range_color=(-10,10),
        center = {'lat':31.969, 'lon': -99.9018},
        zoom = 4.8,
        height=590, width=595,
        mapbox_style = "white-bg",       
        custom_data = [data['County Name'],self.___]
        )
        hovertemp = ''
        hovertemp = '%{customdata[0]}<br>'
        if self.____ == '3rd':
            hovertemp += '%{customdata[1]}% change in ' + self._ + ' 3rd grade students.'
        elif self.____ == '4th':
            hovertemp += '%{customdata[1]}% change in ' + self._ + ' 4th grade students.'
        elif self.____ == '5th':
            hovertemp += '%{customdata[1]}% change in ' + self._ + ' 5th grade students.'
        elif self.____ == '6th':
            hovertemp += '%{customdata[1]}% change in ' + self._ + ' 6th grade students.'
        elif self.____ == '7th':
            hovertemp += '%{customdata[1]}% change in ' + self._ + ' 7th grade students.'
        elif self.____ == '8th':
            hovertemp += '%{customdata[1]}% change in ' + self._ + ' 8th grade students.'
        fig.update_traces(hovertemplate=hovertemp)
        fig.update_geos(fitbounds='locations')
        fig.update_layout(hoverlabel=dict(bgcolor='black',font_size=24,font_family="Times New Roman"),
        font=dict(family='times new roman',
        size=24,color='black'),                
        margin={"r":10,"t":0,"l":10,"b":0})
        fig.update_layout(coloraxis_colorbar=dict(tickvals=[-8,-4,0,4,8],ticktext=['-10','-5','0','5','10'])),
        fig.update_coloraxes(cmid=0,colorbar_orientation='h',colorbar_y=-.148,colorbar_title_font_family='Times New Roman',
                             colorbar_title_font_size=20,colorbar_title_side='bottom', colorbar_thickness=4)
        return fig
    def get_description(self):
        if self.____ == '3rd':
            if self.__ == '2019-2021':
                if self._ == 'All':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in All 3rd grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'White':
                    description = pn.pane.HTML('The percent difference in STAAR scores in White 3rd grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Black':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Black 3rd grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Free Lunch':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in Free Lunch qualified 3rd grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Hispanic':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Hispanic 3rd grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._== 'Poverty':
                    description = pn.pane.HTML('The percent difference in STAAR scores in lower economic status 3rd grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Special-Ed':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Special Education 3rd grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
            elif self.__ == '2021-2022':
                if self._ == 'All':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in All 3rd grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'White':
                    description = pn.pane.HTML('The percent difference in STAAR scores in White 3rd grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Black':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Black 3rd grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Free Lunch':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in Free Lunch qualified 3rd grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Hispanic':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Hispanic 3rd grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._== 'Poverty':
                    description = pn.pane.HTML('The percent difference in STAAR scores in lower economic status 3rd grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Special-Ed':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Special Education 3rd grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
            elif self.__ == '2019-2022':
                if self._ == 'All':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in All 3rd grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'White':
                    description = pn.pane.HTML('The percent difference in STAAR scores in White 3rd grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Black':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Black 3rd grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Free Lunch':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in Free Lunch qualified 3rd grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Hispanic':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Hispanic 3rd grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._== 'Poverty':
                    description = pn.pane.HTML('The percent difference in STAAR scores in lower economic status 3rd grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Special-Ed':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Special Education 3rd grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
        elif self.____ == '4th':
            if self.__ == '2019-2021':
                if self._ == 'All':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in All 4th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'White':
                    description = pn.pane.HTML('The percent difference in STAAR scores in White 4th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Black':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Black 4th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Free Lunch':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in Free Lunch qualified 4th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Hispanic':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Hispanic 4th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._== 'Poverty':
                    description = pn.pane.HTML('The percent difference in STAAR scores in lower economic status 4th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Special-Ed':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Special Education 4th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
            elif self.__ == '2021-2022':
                if self._ == 'All':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in All 4th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'White':
                    description = pn.pane.HTML('The percent difference in STAAR scores in White 4th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Black':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Black 4th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Free Lunch':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in Free Lunch qualified 4th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Hispanic':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Hispanic 4th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._== 'Poverty':
                    description = pn.pane.HTML('The percent difference in STAAR scores in lower economic status 4th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Special-Ed':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Special Education 4th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
            elif self.__ == '2019-2022':
                if self._ == 'All':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in All 4th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'White':
                    description = pn.pane.HTML('The percent difference in STAAR scores in White 4th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Black':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Black 4th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Free Lunch':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in Free Lunch qualified 4th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Hispanic':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Hispanic 4th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._== 'Poverty':
                    description = pn.pane.HTML('The percent difference in STAAR scores in lower economic status 4th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Special-Ed':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Special Education 4th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
        elif self.____ == '5th':
            if self.__ == '2019-2021':
                if self._ == 'All':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in All 5th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'White':
                    description = pn.pane.HTML('The percent difference in STAAR scores in White 5th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Black':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Black 5th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Free Lunch':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in Free Lunch qualified 5th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Hispanic':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Hispanic 5th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._== 'Poverty':
                    description = pn.pane.HTML('The percent difference in STAAR scores in lower economic status 5th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Special-Ed':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Special Education 5th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
            elif self.__ == '2021-2022':
                if self._ == 'All':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in All 5th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'White':
                    description = pn.pane.HTML('The percent difference in STAAR scores in White 5th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Black':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Black 5th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Free Lunch':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in Free Lunch qualified 5th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Hispanic':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Hispanic 5th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._== 'Poverty':
                    description = pn.pane.HTML('The percent difference in STAAR scores in lower economic status 5th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Special-Ed':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Special Education 5th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
            elif self.__ == '2019-2022':
                if self._ == 'All':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in All 5th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'White':
                    description = pn.pane.HTML('The percent difference in STAAR scores in White 5th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Black':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Black 5th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Free Lunch':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in Free Lunch qualified 5th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Hispanic':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Hispanic 5th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._== 'Poverty':
                    description = pn.pane.HTML('The percent difference in STAAR scores in lower economic status 5th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Special-Ed':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Special Education 5th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
        elif self.____ == '6th':
            if self.__ == '2019-2021':
                if self._ == 'All':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in All 6th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'White':
                    description = pn.pane.HTML('The percent difference in STAAR scores in White 6th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Black':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Black 6th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Free Lunch':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in Free Lunch qualified 6th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Hispanic':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Hispanic 6th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._== 'Poverty':
                    description = pn.pane.HTML('The percent difference in STAAR scores in lower economic status 6th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Special-Ed':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Special Education 6th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
            elif self.__ == '2021-2022':
                if self._ == 'All':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in All 6th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'White':
                    description = pn.pane.HTML('The percent difference in STAAR scores in White 6th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Black':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Black 6th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Free Lunch':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in Free Lunch qualified 6th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Hispanic':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Hispanic 6th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._== 'Poverty':
                    description = pn.pane.HTML('The percent difference in STAAR scores in lower economic status 6th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Special-Ed':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Special Education 6th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
            elif self.__ == '2019-2022':
                if self._ == 'All':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in All 6th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'White':
                    description = pn.pane.HTML('The percent difference in STAAR scores in White 6th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Black':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Black 6th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Free Lunch':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in Free Lunch qualified 6th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Hispanic':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Hispanic 6th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._== 'Poverty':
                    description = pn.pane.HTML('The percent difference in STAAR scores in lower economic status 6th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Special-Ed':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Special Education 6th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
        elif self.____ == '7th':
            if self.__ == '2019-2021':
                if self._ == 'All':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in All 7th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'White':
                    description = pn.pane.HTML('The percent difference in STAAR scores in White 7th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Black':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Black 7th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Free Lunch':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in Free Lunch qualified 7th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Hispanic':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Hispanic 7th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._== 'Poverty':
                    description = pn.pane.HTML('The percent difference in STAAR scores in lower economic status 7th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Special-Ed':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Special Education 7th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
            elif self.__ == '2021-2022':
                if self._ == 'All':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in All 7th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'White':
                    description = pn.pane.HTML('The percent difference in STAAR scores in White 7th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Black':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Black 7th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Free Lunch':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in Free Lunch qualified 7th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Hispanic':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Hispanic 7th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._== 'Poverty':
                    description = pn.pane.HTML('The percent difference in STAAR scores in lower economic status 7th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Special-Ed':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Special Education 7th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
            elif self.__ == '2019-2022':
                if self._ == 'All':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in All 7th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'White':
                    description = pn.pane.HTML('The percent difference in STAAR scores in White 7th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Black':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Black 7th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Free Lunch':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in Free Lunch qualified 7th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Hispanic':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Hispanic 7th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._== 'Poverty':
                    description = pn.pane.HTML('The percent difference in STAAR scores in lower economic status 7th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Special-Ed':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Special Education 7th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
        elif self.____ == '8th':
            if self.__ == '2019-2021':
                if self._ == 'All':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in All 8th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'White':
                    description = pn.pane.HTML('The percent difference in STAAR scores in White 8th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Black':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Black 8th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Free Lunch':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in Free Lunch qualified 8th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Hispanic':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Hispanic 8th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._== 'Poverty':
                    description = pn.pane.HTML('The percent difference in STAAR scores in lower economic status 8th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Special-Ed':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Special Education 8th grade students between 2019 and 2021 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
            elif self.__ == '2021-2022':
                if self._ == 'All':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in All 8th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'White':
                    description = pn.pane.HTML('The percent difference in STAAR scores in White 8th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Black':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Black 8th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Free Lunch':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in Free Lunch qualified 8th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Hispanic':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Hispanic 8th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._== 'Poverty':
                    description = pn.pane.HTML('The percent difference in STAAR scores in lower economic status 8th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Special-Ed':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Special Education 8th grade students between 2021 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
            elif self.__ == '2019-2022':
                if self._ == 'All':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in All 8th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'White':
                    description = pn.pane.HTML('The percent difference in STAAR scores in White 8th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Black':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Black 8th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Free Lunch':
                    description = pn.pane.HTML('The percent difference in STAAR Scores in Free Lunch qualified 8th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Hispanic':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Hispanic 8th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._== 'Poverty':
                    description = pn.pane.HTML('The percent difference in STAAR scores in lower economic status 8th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
                elif self._ == 'Special-Ed':
                    description = pn.pane.HTML('The percent difference in STAAR scores in Special Education 8th grade students between 2019 and 2022 for a county.',
                            style={'color':'black','font-size':'20px','width':'110%',
                                  'text-align':'left',
                                  'font-family':'Times New Roman'})
        return description
    def panel(self):
        return pn.Row(
            pn.Column(
            pn.pane.HTML("""<h1>Select A Variable To View At The County Level</h1>""",
                              style={'color':'black','font-size':'14px','width':'100%',
                                     'text-align':'center',
                                     'font-family':'Times New Roman'}),
            pn.Param(self,width=425,background='#FFFFFF',
            widgets={'__':{'widget_type':pn.widgets.RadioButtonGroup},
                    '___':{'widget_type':pn.widgets.RadioButtonGroup},
                    '____':{'widget_type':pn.widgets.RadioButtonGroup}}),
            pn.Spacer(height=25),
            pn.pane.HTML("""<h1>What does this variable show us?</h1>""",
                            style={'color':'black','font-size':'14px','width':'100%',
                                  'text-align':'center',
                                  'font-family':'Times New Roman'}),
            #pn.Spacer(height= 5),
            self.get_description
            ),
            pn.Spacer(width=150),
            self.get_map
        )
dashboard = MapDashboard(name='')
map_component1 = dashboard.panel()
map_component1
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'7445675c-2343-4e60-beb0-d1947f722f94': {'defs': …

# %% [markdown]
# # Heatmap & Histogram

# %%
#Import dataframe
address = ("Data/District_Loss/heat_df.csv")
heat_df = pd.read_csv(address)
#Group the dataset by demographic group
heat_df= heat_df.set_index('group')

# %%
heat1921 = pd.read_excel("Data/District_Loss/heat1921.xlsx")
heat1921 = heat1921.set_index('group')

heat1922 = pd.read_excel("Data/District_Loss/heat1922.xlsx")
heat1922 = heat1922.set_index('group')

heat2122 = pd.read_excel("Data/District_Loss/heat2122.xlsx")
heat2122 = heat2122.set_index('group')

# %%
heat1921
# Out:
#             subject       3rd       4th       5th       6th       7th  \
# group
# All            Math -0.048330 -0.036375 -0.003679 -0.016020 -0.073340
# Asian          Math -0.054235 -0.044694 -0.008467 -0.030249 -0.081712
# Black          Math -0.062425 -0.046983 -0.013881 -0.020411 -0.074143
# Free Lunch     Math -0.052935 -0.040087 -0.004892 -0.016930 -0.074014
# Hispanic       Math -0.052544 -0.041044 -0.003416 -0.017272 -0.075841
# Poverty        Math -0.051965 -0.039868 -0.004038 -0.017514 -0.073660
# Special Ed     Math -0.040454 -0.032465  0.006543 -0.002194 -0.060570
# T1             Math -0.049197 -0.037276 -0.003468 -0.016185 -0.073582
# All         Reading -0.002829  0.009321 -0.014458 -0.001719  0.008341
# Asian       Reading -0.017109  0.006061 -0.013353 -0.002133  0.003671
# Black       Reading -0.011363  0.009308 -0.024429 -0.001806  0.008097
# Free Lunch  Reading -0.005329  0.007507 -0.016098 -0.001785  0.007979
# ...

# %%
heat_df
# Out:
#              subject    3.0    4.0    5.0    6.0    7.0    8.0
# group
# All             Math  0.054  0.041  0.011  0.023  0.071  0.006
# Asian           Math  0.054  0.044  0.009  0.031  0.077  0.002
# Black           Math  0.056  0.042  0.011  0.019  0.065  0.004
# Free Lunch      Math  0.057  0.041  0.011  0.023  0.069  0.006
# Hispanic        Math  0.056  0.043  0.012  0.024  0.071  0.007
# Poverty         Math  0.056  0.042  0.012  0.023  0.070  0.007
# Special Ed      Math  0.044  0.033 -0.001  0.006  0.051 -0.010
# T1              Math  0.055  0.042  0.011  0.025  0.071  0.009
# White           Math  0.045  0.032  0.008  0.018  0.070  0.001
# All          Reading  0.015 -0.003  0.028  0.006 -0.002  0.005
# Asian        Reading  0.017 -0.004  0.023  0.004 -0.004  0.001
# Black        Reading  0.010 -0.006  0.031  0.003 -0.004  0.002
# Free Lunch   Reading  0.017 -0.002  0.030  0.006 -0.002  0.003
# Hispanic     Reading  0.017 -0.002  0.028  0.006 -0.002  0.004
# ...

# %%
heat1922['3rd'] = heat1922['3rd']*100
heat1922['4th'] = heat1922['4th']*100
heat1922['5th'] = heat1922['5th']*100
heat1922['6th'] = heat1922['6th']*100
heat1922['7th'] = heat1922['7th']*100
heat1922['8th'] = heat1922['8th']*100
heat1922=heat1922.round(2)

# %%
heat1921['3rd'] = heat1921['3rd']*100
heat1921['4th'] = heat1921['4th']*100
heat1921['5th'] = heat1921['5th']*100
heat1921['6th'] = heat1921['6th']*100
heat1921['7th'] = heat1921['7th']*100
heat1921['8th'] = heat1921['8th']*100
heat1921=heat1921.round(2)

# %%
heat2122['3rd'] = heat2122['3rd']*100
heat2122['4th'] = heat2122['4th']*100
heat2122['5th'] = heat2122['5th']*100
heat2122['6th'] = heat2122['6th']*100
heat2122['7th'] = heat2122['7th']*100
heat2122['8th'] = heat2122['8th']*100
heat2122=heat2122.round(2)

# %%
heat1922
# Out:
#             subject   3rd   4th   5th   6th   7th   8th
# group
# All            Math -1.19  4.13  2.40 -2.31 -9.15  0.64
# Asian          Math -0.96  3.67  1.57 -3.30 -9.62  0.57
# Black          Math -1.93  3.49  2.25 -2.51 -9.32  0.34
# Free Lunch     Math -1.42  3.88  2.57 -2.31 -9.22  0.53
# Hispanic       Math -1.42  3.96  2.65 -2.45 -9.28  0.57
# Poverty        Math -1.39  3.95  2.58 -2.28 -9.18  0.55
# Special Ed     Math -0.55  4.65  3.42 -0.84 -8.01  1.39
# T1             Math -1.15  4.15  2.51 -2.24 -9.08  0.80
# All         Reading -2.70  3.06  0.71  0.17 -0.81  0.60
# Asian       Reading -3.26  3.40  0.49 -0.45 -1.15  0.29
# Black       Reading -3.33  3.45  0.25 -0.61 -0.70  0.87
# Free Lunch  Reading -2.72  3.22  0.77  0.15 -0.78  0.82
# Hispanic    Reading -2.82  3.16  1.05  0.07 -0.96  0.89
# Poverty     Reading -2.70  3.28  0.74  0.21 -0.76  0.76
# Special Ed  Reading -2.34  3.84  0.32  0.65 -0.46  1.49
# T1          Reading -2.64  3.17  0.81  0.23 -0.68  0.82

# %%
heat_df['3.0'] = heat_df['3.0']*-1
heat_df['4.0'] = heat_df['4.0']*-1
heat_df['5.0'] = heat_df['5.0']*-1
heat_df['6.0'] = heat_df['6.0']*-1
heat_df['7.0'] = heat_df['7.0']*-1
heat_df['8.0'] = heat_df['8.0']*-1
heat_df['3.0'] = heat_df['3.0']*100
heat_df['4.0'] = heat_df['4.0']*100
heat_df['5.0'] = heat_df['5.0']*100
heat_df['6.0'] = heat_df['6.0']*100
heat_df['7.0'] = heat_df['7.0']*100
heat_df['8.0'] = heat_df['8.0']*100
heat_df=heat_df.round(2)
heat_df.rename(columns={'3.0':'3rd',
                      '4.0':'4th',
                      '5.0':'5th',
                      '6.0':'6th',
                      '7.0':'7th',
                      '8.0':'8th'},inplace=True)

# %%
heat_df
# Out:
#              subject  3rd  4th  5th  6th  7th  8th
# group
# All             Math -5.4 -4.1 -1.1 -2.3 -7.1 -0.6
# Asian           Math -5.4 -4.4 -0.9 -3.1 -7.7 -0.2
# Black           Math -5.6 -4.2 -1.1 -1.9 -6.5 -0.4
# Free Lunch      Math -5.7 -4.1 -1.1 -2.3 -6.9 -0.6
# Hispanic        Math -5.6 -4.3 -1.2 -2.4 -7.1 -0.7
# Poverty         Math -5.6 -4.2 -1.2 -2.3 -7.0 -0.7
# Special Ed      Math -4.4 -3.3  0.1 -0.6 -5.1  1.0
# T1              Math -5.5 -4.2 -1.1 -2.5 -7.1 -0.9
# White           Math -4.5 -3.2 -0.8 -1.8 -7.0 -0.1
# All          Reading -1.5  0.3 -2.8 -0.6  0.2 -0.5
# Asian        Reading -1.7  0.4 -2.3 -0.4  0.4 -0.1
# Black        Reading -1.0  0.6 -3.1 -0.3  0.4 -0.2
# Free Lunch   Reading -1.7  0.2 -3.0 -0.6  0.2 -0.3
# Hispanic     Reading -1.7  0.2 -2.8 -0.6  0.2 -0.4
# Poverty      Reading -1.7  0.2 -2.9 -0.6  0.2 -0.3
# Special Ed   Reading -1.1  0.7 -2.8  0.3  0.6  0.8
# T1           Reading -1.6  0.2 -2.8 -0.6  0.1 -0.5
# ...

# %%
#Creates a heatmap based off of the STAAR/Percent Loss Data by demographic group and grade
subject_inputs = ['Math','Reading']
year_list = ['2019-2021','2021-2022','2019-2022']
class LossDashboard(param.Parameterized):
    Subject = param.Selector(subject_inputs,default = subject_inputs[0])
    __ = param.Selector(year_list, default=year_list[0])
    #@param.depends('Subject')
    def lossplot(self):
        if self.__ == '2019-2021':
            data = heat1921[heat1921['subject'] == self.Subject]
        elif self.__ == '2019-2022':
            data = heat1922[heat1922['subject'] == self.Subject]
        elif self.__ == '2021-2022':
            data = heat2122[heat2122['subject'] == self.Subject]
#        data = heat_df[heat_df['subject'] == self.Subject]
        data = data.drop(['subject'],axis=1)
        fig = px.imshow(data, labels=dict(x='Grade',y='Demographic Group',color='Learning Loss %'),text_auto='.1f',
        height=630,width=1100,
        color_continuous_scale='balance_r',
       # labels={'Learning Loss':'Learning Loss '}
        range_color=(-5,5),
        aspect='none')
        fig.update_layout(hoverlabel=dict(bgcolor='black',font_size=24,font_family="Times New Roman"),
        font=dict(family='times new roman',
        size=28,color='black'),
        title_x=.96,                
        margin={"r":10,"t":10,"l":0,"b":15})
        fig.update_coloraxes(cmid=0,colorbar_title_font_family='Times New Roman',colorbar_title_text='% Loss',
                             colorbar_title_font_size=24,colorbar_title_side='bottom',colorbar_thickness=10)
        return fig
    def panel(self):
        return pn.Row(
          #  pn.Param(self, width=350, name='Normalized Difference in STAAR Scores Between 2019 and 2021 By Demographic Group and Grade:',sizing_mode = 'fixed',background='#FFFFFF'),  
            pn.Param(self,width=300,background='#FFFFFF',
            widgets={'__':{'widget_type':pn.widgets.RadioButtonGroup}}),
            pn.Spacer(width=80),
            self.lossplot
        )
dashboard = LossDashboard(name = 'Normalized Difference in STAAR Scores By Demographic Group and Grade')
loss_component2 = dashboard.panel()
loss_component2
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'2e38a291-5660-4cb6-a5d8-c9a21f2f29fe': {'defs': …

# %% [markdown]
# # County Level Dashboard

# %%
#Panel HTML elements can take a 'style' parameter directly. 
#You could alternatively assign a css class as above and include the css code in raw_css
title_html_pane = pn.pane.HTML("""<h1>Learning Loss Recovery after COVID-19 Pandemic in Texas Public Schools</h1>""",
                              style={'color':'white','font-size':'20px','width':'145%',
                                     'background-color':'#6A5638','text-align':'center',
                                     'outline-style':'solid','outline-color':'#30231D',
                                     'outline-width':'thick','font-family':'Times New Roman'})
#datalab_img = pn.pane.PNG("C:/Users/Daniel Payan/Downloads/dataimg.png",height=220,width=410)
#txst_img = pn.pane.PNG("C:/Users/Daniel Payan/Downloads/txst1.png",width=410, height=220)
datalab_img = pn.pane.PNG("Data/Images/datalabimage.png",height=171,width=280)
txst_img = pn.pane.PNG("Data/Images/THRClogo.png",height=140,width=350)


title_bar = pn.Row(pn.Spacer(width=30),datalab_img,pn.Spacer(width=55),title_html_pane,pn.Spacer(width=310),txst_img)

content_bar = pn.Row(pn.Spacer(width=255),map_component1)

#Create a new gridspec with 14 columns and 12 rows
gspec = pn.GridSpec(ncols=14,nrows=6, background='#FFFFFF',sizing_mode='stretch_both')
#Place application elements in the grid, using pn.Spacer() for improved layout spacing and control
gspec[0, 7] = title_bar
gspec[1:6, 7] = content_bar
gspec.show()
# Out:
# Launching server at http://localhost:63706

# %% [markdown]
# # Heatmap & Histogram Dashboard

# %%
#Panel HTML elements can take a 'style' parameter directly. 
#You could alternatively assign a css class as above and include the css code in raw_css
title_html_pane = pn.pane.HTML("""<h1>Learning Loss Recovery after COVID-19 Pandemic in Texas Public Schools</h1>""",
                              style={'color':'white','font-size':'20px','width':'145%',
                                     'background-color':'#6A5638','text-align':'center',
                                     'outline-style':'solid','outline-color':'#30231D',
                                     'outline-width':'thick','font-family':'Times New Roman'})
#datalab_img = pn.pane.PNG("C:/Users/Daniel Payan/Downloads/dataimg.png",height=220,width=410)
#txst_img = pn.pane.PNG("C:/Users/Daniel Payan/Downloads/txst1.png",width=410, height=220)
datalab_img = pn.pane.PNG("Data/Images/datalabimage.png",height=171,width=280)
txst_img = pn.pane.PNG("Data/Images/THRClogo.png",height=140,width=350)



title_bar = pn.Row(pn.Spacer(width=30),datalab_img,pn.Spacer(width=55),title_html_pane,pn.Spacer(width=310),txst_img)

content_bar = pn.Row(pn.Spacer(width=130),loss_component2)

#Create a new gridspec with 14 columns and 12 rows
gspec = pn.GridSpec(ncols=14,nrows=6, background='#FFFFFF',sizing_mode='stretch_both')
#Place application elements in the grid, using pn.Spacer() for improved layout spacing and control
gspec[0, 7] = title_bar
gspec[2:6, 7] = content_bar
gspec.show()
# Out:
# Launching server at http://localhost:63707
